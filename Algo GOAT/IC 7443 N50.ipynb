# %%
from fyers_apiv3 import fyersModel
from fyers_apiv3.FyersWebsocket import data_ws

import pandas as pd
import numpy as np
import math

import datetime as dt
from datetime import date, timedelta,datetime
import time 

from fyers_apiv3.FyersWebsocket import data_ws
import csv

import matplotlib.pyplot as plt
import mplfinance as mpf

import scipy

from  time import sleep
import threading
import os
import pyotp
import requests
import json
import pytz
from urllib.parse import parse_qs,urlparse
import base64

import warnings
pd.set_option('display.max_columns', None)
warnings.filterwarnings('ignore')

# %%
redirect_uri = "https://trade.fyers.in/api-login/redirect-uri/index.html"
client_id='HTHFWXFS49-100'
secret_key = 'JOQVVTY9UJ'
FY_ID = "YB00632"  
TOTP_KEY = "3Y7PAJSPNHXEADGRDD726MLHJW43AJGH"  
PIN = "1964" 

grant_type = "authorization_code"                  
response_type = "code"                         
state = "sample"                                  

appSession = fyersModel.SessionModel(client_id = client_id, redirect_uri = redirect_uri,response_type=response_type,state=state,secret_key=secret_key,grant_type=grant_type)


generateTokenUrl = appSession.generate_authcode()
generateTokenUrl


def getEncodedString(string):
    string = str(string)
    base64_bytes = base64.b64encode(string.encode("ascii"))
    return base64_bytes.decode("ascii")
  



URL_SEND_LOGIN_OTP="https://api-t2.fyers.in/vagator/v2/send_login_otp_v2"
res = requests.post(url=URL_SEND_LOGIN_OTP, json={"fy_id":getEncodedString(FY_ID),"app_id":"2"}).json()   
print(res) 

if datetime.now().second % 30 > 27 : sleep(5)
URL_VERIFY_OTP="https://api-t2.fyers.in/vagator/v2/verify_otp"
res2 = requests.post(url=URL_VERIFY_OTP, json= {"request_key":res["request_key"],"otp":pyotp.TOTP(TOTP_KEY).now()}).json()  
print(res2) 


ses = requests.Session()
URL_VERIFY_OTP2="https://api-t2.fyers.in/vagator/v2/verify_pin_v2"
payload2 = {"request_key": res2["request_key"],"identity_type":"pin","identifier":getEncodedString(PIN)}
res3 = ses.post(url=URL_VERIFY_OTP2, json= payload2).json()  
print(res3) 


ses.headers.update({
    'authorization': f"Bearer {res3['data']['access_token']}"
})


TOKENURL="https://api-t1.fyers.in/api/v3/token"
payload3 = {"fyers_id":FY_ID,
           "app_id":client_id[:-4],
           "redirect_uri":redirect_uri,
           "appType":"100","code_challenge":"",
           "state":"None","scope":"","nonce":"","response_type":"code","create_cookie":True}

res3 = ses.post(url=TOKENURL, json= payload3).json()  
print(res3)


url = res3['Url']
print(url)
parsed = urlparse(url)
auth_code = parse_qs(parsed.query)['auth_code'][0]
auth_code


grant_type = "authorization_code" 

response_type = "code"  

session = fyersModel.SessionModel(
    client_id=client_id,
    secret_key=secret_key, 
    redirect_uri=redirect_uri, 
    response_type=response_type, 
    grant_type=grant_type
)

session.set_token(auth_code)

response = session.generate_token()

#print(response)

access_token = response['access_token']

fyers = fyersModel.FyersModel(client_id=client_id, is_async=False, token=access_token, log_path=os.getcwd())
fyers.get_profile()
# Out:
# {'s': 'ok', 'code': 1043, 'client_name': 'Baban Maruti Pawar', 'nick_name': 'Baban', 'pin_created': True, 'totp_enabled': True, 'avatar_link': None, 'message': 'user exist', 'mobile_no': '89xxxxxx82', 'email_id': 'bxxxxxxxxxxxx5@gmail.com', 'request_key': 'eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9..-mnYJoCke7PQ7hK0-qSxiJ5NFjMXf0QkyLB7ds43NKQ'}
# {'s': 'ok', 'code': 2, 'request_key': 'eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJpYXQiOjE3MDQxNzAyMjcsImV4cCI6MTcwNDI1NjYyNywibmJmIjoxNzA0MTcwMjI3LCJmeV9pZCI6IllCMDA2MzIiLCJyZXF1ZXN0X2tleSI6ImJvMEhkSTV0cGprZHdiQ010V1JXdERVQ0FhWDRzTHBFTW1VdktFUzdzWVYwT3NIeDJIIn0.G_5pDPVlhNOXItkV7_rq18R6d-1kkmiyhDYiXLhSKPc', 'client_name': 'Baban Maruti Pawar', 'nick_name': 'Baban', 'pin_created': True, 'message': 'fy_id and OTP verified successfully'}
# {'s': 'ok', 'code': 1004, 'message': 'Pin is Verified', 'data': {'refresh_token': 'eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.....Z5qva3uJzZWwNu58_FuF-LPwk1OCKu9lXUT15m637OQ', 'access_token': 'eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.....NH7n4Cn_KK2zQ1nZJs8_oq2RA4fz_-Pe5pbeLajIbLY'}}
# {'s': 'ok', 'code': 308, 'message': '', 'cookie': '_FYERS=eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9..LJ7J0KWjmvEn-35DoEXe1M-luh47plhW79JdMP2tx54', 'Url': 'https://trade.fyers.in/api-login/redirect-uri/index.html?s=ok&code=200&auth_code=eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.....rMhBeMp16QlxECIdtE24kXUQROcbYoSSSBNmBEnhma0&state=None'}
# https://trade.fyers.in/api-login/redirect-uri/index.html?s=ok&code=200&auth_code=eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.....rMhBeMp16QlxECIdtE24kXUQROcbYoSSSBNmBEnhma0&state=None
# {'s': 'ok',
#  'code': 200,
#  'message': '',
#  'data': {'fy_id': 'YB00632',
#   'name': 'BABAN MARUTI PAWAR',
#   'image': None,
#   'display_name': None,
#   'pin_change_date': '21-12-2023 21:01:26',
#   'email_id': 'babanpawar8975@gmail.com',
#   'pwd_change_date': None,
#   'PAN': '---------',
#   'mobile_number': '8975963982',
#   'totp': True,
#   'pwd_to_expire': 90}}

# %%
start_date = date.today()
end_date = date.today()
print("Start Date:", start_date)
print("End Date:", end_date)
# Out:
# Start Date: 2024-01-02
# End Date: 2024-01-02

# %% [markdown]
# stdate_str = input("Enter the previous active market date (YYYY-MM-DD): ")

# %%
csv_file_path = 'today_lvls.csv'

# Create an empty list to store values from column N
lvl = []

# Open the CSV file
with open(csv_file_path, 'r') as file:
    # Create a CSV reader object using DictReader
    csv_reader = csv.DictReader(file)

    # Iterate over the rows in the CSV file
    for row in csv_reader:
        # Assuming 'N' is the header for the column
        # Append the value from column 'N' to the list
        lvl.append(float(row['N']))

# Now, 'column_n_values' contains all the values from column 'N'
print("lvl:", lvl)
# Out:
# lvl: [21875.0, 21833.0, 21778.0, 21730.0, 21679.0, 21629.0, 21616.0]

# %%
historydata = pd.DataFrame()

# %%
def gethistorydata(st,ed,res):
    data = {
            "symbol":"NSE:NIFTY50-INDEX",
            "resolution":str(res),
            "date_format":"1",
            "range_from":start_date,
            "range_to":end_date,
            "cont_flag":"0"
            }
    global historydata
    repo = fyers.history(data=data)
    #print(repo)
    data = pd.DataFrame.from_dict(repo['candles'])
    #global cols
    cols = ['datetime', 'open', 'high','low','close', 'volume']
    data.columns = cols
    
    data['datetime'] = pd.to_datetime(data['datetime'],unit="s")
    data['datetime'] = data['datetime'].dt.tz_localize('utc').dt.tz_convert('Asia/Kolkata')
    
    #data = data.set_index('datetime')
    historydata = data
    historydata['datetime'] = pd.to_datetime(historydata['datetime'])
    historydata.set_index('datetime', inplace=True)

#     historydata['date'] = historydata['datetime'].dt.date
# #     historydata.set_index('date', inplace=True)
#     historydata['time'] = historydata['datetime'].dt.time

#     historydata.drop(columns=['datetime'], inplace=True)
    historydata.drop(columns=['volume'], inplace=True)
    
    #append(historydata,data)],axis=0)
    #historydata.to_csv("75op.csv")
#     print(historydata)

# %%
gethistorydata(start_date,end_date,5)

# %%
def pointchecker(pt,rg):
    point_value = pt
    
    for level in lvl:
        if abs(point_value - level) <= rg:
            return True
    else:
            return False

# %%
def plot_tolerance_range(level, arr, tolerance=15, color='lightblue', alpha=0.3):
    lower_bound = level - tolerance
    upper_bound = level + tolerance
    plt.fill_between(range(len(arr)), lower_bound, upper_bound, color=color, alpha=alpha,label='level range')

# %%
global historydata

sl=0
target=0
rrr = 0

ready=0
count=0
status =0
tobs = 0

# %%
def plot_candles():
    mpf.plot(historydata, type='candle', style='yahoo', title='Candlestick Chart', ylabel='Price', hlines=lvl)

# %%
def count_candles(df, start_candle_value_high, start_candle_value_low, end_candle_value_high, end_candle_value_low, candle_value_column1="high", candle_value_column2="low"):
    counts = 0
#     df.set_index('date', inplace=True)
    #df = df.iloc[:11]

    
    for index, row in df.iterrows():
        candle_high = row[candle_value_column1]
        candle_low = row[candle_value_column2]
        
        if(start_candle_value_high > candle_high and start_candle_value_low < candle_low):
            counts += 1
        else:
            count=0
            break
            
    return counts

# %%
def find_closest_level(point, levels, direction='upward'):
    closest_level = None
    min_distance = float('inf')

    for level in levels:
        distance = abs(level - point)

        if direction == 'upward' and level > point:
            if distance < min_distance:
                min_distance = distance
                closest_level = level
        elif direction == 'downward' and level < point:
            if distance < min_distance:
                min_distance = distance
                closest_level = level

    return closest_level

# %%
def count_back_to_back_within_range(dataframe, column_name, target_value, margin):
    if len(dataframe) < 2:
        return 0

    # Iterate over rows to check back-to-back condition
    count_of_back_to_back = 0
    for i in range(1, len(dataframe)):
        current_value = dataframe[column_name].iloc[i]
        previous_value = dataframe[column_name].iloc[i - 1]

        # Check if current and previous values are within the specified range
        if (current_value >= target_value - margin) and (current_value <= target_value + margin) and \
           (previous_value >= target_value - margin) and (previous_value <= target_value + margin):
            count_of_back_to_back += 1

    return count_of_back_to_back

# %% [raw]
# count_candles(historydata, historydata['high'].iloc[0],historydata['low'].iloc[0], historydata['high'].iloc[11], historydata['low'].iloc[11])

# %%
global historydata
itr=0
secitr=0
  
neck=0
extra=0
midline=0
sl=0
target=0
rrr = 0

ready=0
count=0
status =0
tobs = 0
secitr=0
point1=0
point2=0
c=0
c1=0

# %%
def onmessage(message):
    print(message,"\ttime: ",time.localtime().tm_hour,time.localtime().tm_min,time.localtime().tm_sec)
    time.sleep(1)
    
    global historydata,itr,sl,target,rrr,ready,count,status,tobs,secitr,point1,point2,c,c1
    
    t = time.localtime()
    cmin = time.strftime("%M", t)
    csec = time.strftime("%S", t)  
#     global tops,bottoms,arr

    if(ready==1 and itr==1):
        c1= count_candles(historydata, historydata['high'].iloc[0],historydata['low'].iloc[0], historydata['high'].iloc[-1], historydata['low'].iloc[-1])
        if (c == c1 and c!=0 and c1!=0 and ((message['ltp'] <= (point1 + 5) and message['ltp'] >= (point1 - 5)) or (message['ltp'] <= (point2 + 5) and message['ltp'] >= (point2 - 5)))):
            print("entry made on: ",message['ltp'])
            entryprice = message['ltp']
            entryhour = time.localtime(time.time()).tm_hour
            entrymin =  time.localtime(time.time()).tm_min
            entrydate = date.today()
            count = count+1
            status = 1
            ready=0
            secitr=1
            start_time = time.time()

    if (int(cmin) % 5 == 0 and int(csec)==1):

        gethistorydata(start_date,end_date,5)  
        plot_candles()
        
        point1 = historydata['high'].iloc[0]
        point2 = historydata['low'].iloc[0]
        
        if(historydata['close'].iloc[-1]>point1 and historydata['close'].iloc[-2]<=point1):
            c= count_candles(historydata, historydata['high'].iloc[0],historydata['low'].iloc[0], historydata['high'].iloc[-1], historydata['low'].iloc[-1])
            if(c>2):
                for i in lvl:
                    if(i<point1 and i>point1-60):
                        sl = i
                        
                    else:
                        sl = point1-60
                        
                target = find_closest_level(point1,lvl) -15
                rrr = (abs(target-point1))/(point1-sl)
                ready=1
                print("\nready e!!!\n")
                            
        elif(historydata['close'].iloc[-1]<point2 and historydata['close'].iloc[-2]<=point2):
            c= count_candles(historydata, historydata['high'].iloc[0],historydata['low'].iloc[0], historydata['high'].iloc[-1], historydata['low'].iloc[-1])
            if(c>2):
                for i in lvl:
                    if(i>point2 and i<point2+60):
                        sl = i
                    else:
                        sl = point2+60
                        
                target = find_closest_level(point1,lvl,direction='downward') + 15
                rrr = (abs(point2-target))/(sl-point2)
                ready=1
                print("\nready e!!!\n")
        

    if(secitr == 0 and ready == 1 and rrr>=0.6 and count<1):
        if(c>2):                
            itr=itr+1
        if (c > 2 and 
        (point1 < historydata['close'].iloc[-1] <= (point1 + 10)) or 
        (point2 - 10) <= historydata['close'].iloc[-1] < point2):

            print("entry made on: ",message['ltp'])
            entryprice = message['ltp']
            entryhour = time.localtime(time.time()).tm_hour
            entrymin =  time.localtime(time.time()).tm_min
            entrydate = date.today()
            count = count+1
            status = 1
            start_time = time.time()

        
    elif(target!=0 and sl!=0 and status==1 and ((message['ltp']>=target or message['ltp']<=sl) or pointchecker(message['ltp'],15)==True)):
        print("entry exited on: ",message['ltp'])
        exitprice = message['ltp']
        status = 0
        ready=0


        with open('ic_backtest_report.csv', 'a', newline='') as csvfile:
            writer = csv.writer(csvfile)
            exitprice = message['ltp']
            exithour = time.localtime(time.time()).tm_hour
            exitmin =  time.localtime(time.time()).tm_min       #historydata.iloc[-1]['time']
            exitdate = date.today()
            pandl = entryprice-exitprice
            new_row = [symbols[0],entrydate,entryhour,entrymin,entryprice,exitdate,exithour,exitmin,exitprice,pandl]
            writer.writerow(new_row)
            print("exported trade data")

        if(message['symbol']=='NSE:NIFTY50-INDEX' and count>=2):
            data_type= "SymbolUpdate"
            symbol_to_unsubscribe= ['NSE:NIFTY50-INDEX']
            wfyers.unsubscribe(symbols= symbol_to_unsubscribe, data_type = data_type)
            print("unsubscribed") 
        
    elif(status==1):
#         while True:
        current_time = time.time()
        elapsed_minutes = int((current_time - start_time) / 60)
        remaining_minutes = target_minutes - elapsed_minutes

        if(remaining_minutes <= 0 ):
            print("entry exited on: ",message['ltp'])
            exitprice = message['ltp']
            status = 0
            ready=0


            with open('ic_backtest_report.csv', 'a', newline='') as csvfile:
                writer = csv.writer(csvfile)
                exitprice = message['ltp']
                exithour = time.localtime(time.time()).tm_hour
                exitmin =  time.localtime(time.time()).tm_min       #historydata.iloc[-1]['time']
                exitdate = date.today()
                pandl = entryprice-exitprice
                new_row = [symbols[0],entrydate,entryhour,entrymin,entryprice,exitdate,exithour,exitmin,exitprice,pandl]
                writer.writerow(new_row)
                print("exported trade data")

            if(message['symbol']=='NSE:NIFTY50-INDEX' and count>=2):
                    data_type= "SymbolUpdate"
                    symbol_to_unsubscribe= ['NSE:NIFTY50-INDEX']
                    wfyers.unsubscribe(symbols= symbol_to_unsubscribe, data_type = data_type)
                    print("unsubscribed") 
#             break

    
    if(status==0 and time.localtime(time.time()).tm_hour>=14 and time.localtime(time.time()).tm_min>=15 and message['symbol']=='NSE:NIFTY50-INDEX'):
        data_type= "SymbolUpdate"
        symbol_to_unsubscribe= ['NSE:NIFTY50-INDEX']
        wfyers.unsubscribe(symbols= symbol_to_unsubscribe, data_type = data_type)
#         print("unsubscribed")


def onerror(message):
    print("Error:", message)


def onclose(message):
    print("Connection closed:", message)


def onopen():
    data_type = "SymbolUpdate"

    symbols = ['NSE:NIFTY50-INDEX']
    wfyers.subscribe(symbols=symbols, data_type=data_type)
    
    wfyers.keep_running()


waccess_token = client_id+":"+access_token 

wfyers = data_ws.FyersDataSocket(
    access_token=waccess_token,       # Access token in the format "appid:accesstoken"
    log_path="",                     # Path to save logs. Leave empty to auto-create logs in the current directory.
    litemode=True,                  # Lite mode disabled. Set to True if you want a lite response.
    write_to_file=False,              # Save response in a log file instead of printing it.
    reconnect=True,                  # Enable auto-reconnection to WebSocket on disconnection.
    on_connect=onopen,               # Callback function to subscribe to data upon connection.
    on_close=onclose,                # Callback function to handle WebSocket connection close events.
    on_error=onerror,                # Callback function to handle WebSocket errors.
    on_message=onmessage            # Callback function to handle incoming messages from the WebSocket.
)

wfyers.connect()
# Out:
# {'type': 'cn', 'code': 200, 'message': 'Authentication done', 's': 'ok'} 	time:  10 7 9
# {'type': 'lit', 'code': 200, 'message': 'Lite Mode On', 's': 'ok'} 	time:  10 7 10
# {'type': 'sub', 'code': 200, 'message': 'Subscribed', 's': 'ok'} 	time:  10 7 11
# {'ltp': 21674.55, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 7 12
# {'ltp': 21674.85, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 7 13
# {'ltp': 21675.65, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 7 14
# {'ltp': 21675.45, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 7 15
# {'ltp': 21676.05, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 7 16
# {'ltp': 21676.55, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 7 17
# {'ltp': 21675.7, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 7 18
# {'ltp': 21675.0, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 7 19
# {'ltp': 21674.95, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 7 20
# {'ltp': 21676.35, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 7 21
# {'ltp': 21674.4, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 7 22
# {'ltp': 21675.5, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 7 23
# {'ltp': 21673.15, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 7 24
# {'ltp': 21673.8, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 7 25
# {'ltp': 21673.05, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 7 26
# {'ltp': 21670.85, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 7 27
# {'ltp': 21670.4, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 7 28
# {'ltp': 21669.45, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 7 29
# {'ltp': 21669.25, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 7 30
# {'ltp': 21668.3, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 7 31
# {'ltp': 21667.85, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 7 32
# {'ltp': 21667.0, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 7 33
# {'ltp': 21667.0, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 7 34
# {'ltp': 21666.4, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 7 35
# {'ltp': 21665.5, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 7 36
# {'ltp': 21668.6, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 7 37
# {'ltp': 21670.1, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 7 38
# {'ltp': 21670.6, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 7 39
# {'ltp': 21670.05, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 7 40
# {'ltp': 21670.55, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 7 41
# {'ltp': 21670.9, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 7 42
# {'ltp': 21670.6, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 7 43
# {'ltp': 21671.2, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 7 44
# {'ltp': 21670.6, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 7 45
# {'ltp': 21671.6, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 7 46
# {'ltp': 21671.4, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 7 47
# {'ltp': 21671.7, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 7 48
# {'ltp': 21672.15, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 7 49
# {'ltp': 21670.95, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 7 50
# {'ltp': 21671.25, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 7 51
# {'ltp': 21669.9, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 7 52
# {'ltp': 21670.2, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 7 53
# {'ltp': 21669.85, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 7 54
# {'ltp': 21669.95, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 7 55
# {'ltp': 21670.55, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 7 56
# {'ltp': 21669.8, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 7 57
# {'ltp': 21670.6, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 7 58
# {'ltp': 21670.1, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 7 59
# {'ltp': 21671.5, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 8 0
# {'ltp': 21671.25, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 8 1
# {'ltp': 21671.1, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 8 2
# {'ltp': 21672.65, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 8 3
# {'ltp': 21672.9, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 8 4
# {'ltp': 21672.0, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 8 5
# {'ltp': 21674.15, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 8 6
# {'ltp': 21672.55, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 8 7
# {'ltp': 21674.65, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 8 8
# {'ltp': 21674.7, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 8 9
# {'ltp': 21673.8, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 8 10
# {'ltp': 21674.4, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 8 11
# {'ltp': 21675.2, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 8 12
# {'ltp': 21673.8, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 8 13
# {'ltp': 21674.55, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 8 14
# {'ltp': 21674.5, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 8 15
# {'ltp': 21673.8, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 8 16
# {'ltp': 21674.85, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 8 17
# {'ltp': 21675.0, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 8 18
# {'ltp': 21675.3, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 8 19
# {'ltp': 21675.35, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 8 20
# {'ltp': 21674.75, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 8 21
# {'ltp': 21673.9, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 8 22
# {'ltp': 21674.65, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 8 23
# {'ltp': 21674.55, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 8 24
# {'ltp': 21674.05, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 8 25
# {'ltp': 21673.25, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 8 26
# {'ltp': 21673.25, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 8 27
# {'ltp': 21672.7, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 8 28
# {'ltp': 21673.35, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 8 29
# {'ltp': 21674.2, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 8 30
# {'ltp': 21673.05, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 8 31
# {'ltp': 21673.35, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 8 32
# {'ltp': 21672.6, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 8 33
# {'ltp': 21672.3, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 8 34
# {'ltp': 21671.65, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 8 35
# {'ltp': 21671.35, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 8 36
# {'ltp': 21672.15, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 8 37
# {'ltp': 21671.5, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 8 39
# {'ltp': 21671.3, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 8 40
# {'ltp': 21668.6, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 8 41
# {'ltp': 21668.65, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 8 42
# {'ltp': 21669.5, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 8 43
# {'ltp': 21668.35, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 8 44
# {'ltp': 21667.5, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 8 45
# {'ltp': 21665.95, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 8 46
# {'ltp': 21665.85, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 8 47
# {'ltp': 21666.25, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 8 48
# {'ltp': 21666.3, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 8 49
# {'ltp': 21666.85, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 8 50
# {'ltp': 21666.2, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 8 51
# {'ltp': 21665.5, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 8 52
# {'ltp': 21665.65, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 8 53
# {'ltp': 21666.35, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 8 54
# {'ltp': 21667.0, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 8 55
# {'ltp': 21665.65, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 8 56
# {'ltp': 21666.05, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 8 57
# {'ltp': 21665.45, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 8 58
# {'ltp': 21666.2, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 8 59
# {'ltp': 21666.1, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 9 0
# {'ltp': 21666.3, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 9 1
# {'ltp': 21666.5, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 9 2
# {'ltp': 21665.45, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 9 3
# {'ltp': 21664.6, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 9 4
# {'ltp': 21664.25, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 9 5
# {'ltp': 21664.3, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 9 6
# {'ltp': 21665.95, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 9 7
# {'ltp': 21665.95, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 9 8
# {'ltp': 21668.05, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 9 9
# {'ltp': 21668.85, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 9 10
# {'ltp': 21669.6, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 9 11
# {'ltp': 21670.05, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 9 12
# {'ltp': 21670.35, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 9 13
# {'ltp': 21671.3, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 9 14
# {'ltp': 21670.55, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 9 15
# {'ltp': 21670.85, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 9 16
# {'ltp': 21670.75, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 9 17
# {'ltp': 21671.0, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 9 18
# {'ltp': 21670.95, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 9 19
# {'ltp': 21670.05, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 9 20
# {'ltp': 21668.9, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 9 21
# {'ltp': 21669.15, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 9 22
# {'ltp': 21668.6, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 9 23
# {'ltp': 21668.8, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 9 24
# {'ltp': 21668.4, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 9 25
# {'ltp': 21668.2, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 9 26
# {'ltp': 21667.95, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 9 27
# {'ltp': 21666.95, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 9 28
# {'ltp': 21667.7, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 9 29
# {'ltp': 21668.1, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 9 30
# {'ltp': 21667.8, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 9 31
# {'ltp': 21667.55, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 9 32
# {'ltp': 21667.65, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 9 33
# {'ltp': 21666.15, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 9 34
# {'ltp': 21666.3, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 9 35
# {'ltp': 21666.2, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 9 36
# {'ltp': 21666.15, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 9 37
# {'ltp': 21665.0, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 9 38
# {'ltp': 21665.35, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 9 39
# {'ltp': 21665.7, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 9 40
# {'ltp': 21665.45, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 9 41
# {'ltp': 21665.15, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 9 42
# {'ltp': 21664.4, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 9 43
# {'ltp': 21663.5, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 9 44
# {'ltp': 21664.0, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 9 45
# {'ltp': 21663.75, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 9 46
# {'ltp': 21663.55, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 9 47
# {'ltp': 21661.4, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 9 48
# {'ltp': 21662.05, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 9 49
# {'ltp': 21663.8, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 9 50
# {'ltp': 21662.8, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 9 51
# {'ltp': 21662.9, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 9 52
# {'ltp': 21662.75, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 9 53
# {'ltp': 21663.05, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 9 54
# {'ltp': 21663.45, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 9 55
# {'ltp': 21663.05, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 9 56
# {'ltp': 21662.85, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 9 57
# {'ltp': 21663.6, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 9 58
# {'ltp': 21664.6, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 9 59
# {'ltp': 21663.75, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 10 0
# ready e!!!
#
# {'ltp': 21663.75, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 10 2
# {'ltp': 21663.95, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 10 3
# {'ltp': 21663.65, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 10 4
# {'ltp': 21663.1, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 10 5
# {'ltp': 21663.35, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 10 6
# {'ltp': 21662.65, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 10 7
# {'ltp': 21663.2, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 10 8
# {'ltp': 21664.45, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 10 9
# {'ltp': 21665.15, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 10 10
# {'ltp': 21664.7, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 10 11
# {'ltp': 21665.55, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 10 12
# {'ltp': 21665.35, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 10 13
# {'ltp': 21664.75, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 10 14
# {'ltp': 21666.25, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 10 15
# {'ltp': 21666.2, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 10 16
# {'ltp': 21666.75, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 10 17
# {'ltp': 21666.3, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 10 18
# {'ltp': 21666.4, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 10 19
# {'ltp': 21666.2, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 10 20
# {'ltp': 21666.35, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 10 21
# {'ltp': 21665.6, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 10 22
# {'ltp': 21664.75, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 10 23
# {'ltp': 21664.75, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 10 24
# {'ltp': 21663.95, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 10 25
# {'ltp': 21664.4, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 10 26
# {'ltp': 21664.05, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 10 27
# {'ltp': 21664.3, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 10 28
# {'ltp': 21663.15, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 10 29
# {'ltp': 21662.9, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 10 30
# {'ltp': 21662.6, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 10 31
# {'ltp': 21663.45, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 10 32
# {'ltp': 21663.2, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 10 33
# {'ltp': 21663.1, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 10 34
# {'ltp': 21662.85, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 10 35
# {'ltp': 21663.1, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 10 36
# {'ltp': 21663.65, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 10 37
# {'ltp': 21664.45, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 10 38
# {'ltp': 21664.65, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 10 39
# {'ltp': 21665.2, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 10 40
# {'ltp': 21665.2, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 10 41
# {'ltp': 21664.45, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 10 42
# {'ltp': 21664.65, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 10 43
# {'ltp': 21664.2, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 10 44
# {'ltp': 21664.25, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 10 45
# {'ltp': 21663.8, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 10 46
# {'ltp': 21663.7, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 10 47
# {'ltp': 21663.35, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 10 48
# {'ltp': 21662.8, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 10 49
# {'ltp': 21661.35, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 10 50
# {'ltp': 21660.45, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 10 51
# {'ltp': 21660.3, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 10 52
# {'ltp': 21661.7, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 10 53
# {'ltp': 21661.15, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 10 55
# {'ltp': 21661.3, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 10 56
# {'ltp': 21660.5, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 10 57
# {'ltp': 21659.75, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 10 58
# {'ltp': 21661.15, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 10 59
# {'ltp': 21661.15, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 11 0
# {'ltp': 21661.5, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 11 1
# {'ltp': 21662.1, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 11 2
# {'ltp': 21661.15, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 11 3
# {'ltp': 21661.5, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 11 4
# {'ltp': 21662.0, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 11 5
# {'ltp': 21661.2, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 11 6
# {'ltp': 21661.75, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 11 7
# {'ltp': 21660.85, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 11 8
# {'ltp': 21661.55, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 11 9
# {'ltp': 21661.8, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 11 10
# {'ltp': 21662.25, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 11 11
# {'ltp': 21661.8, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 11 12
# {'ltp': 21661.85, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 11 13
# {'ltp': 21661.8, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 11 14
# {'ltp': 21663.45, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 11 15
# {'ltp': 21664.0, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 11 16
# {'ltp': 21663.75, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 11 17
# {'ltp': 21665.2, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 11 18
# {'ltp': 21664.85, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 11 19
# {'ltp': 21665.7, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 11 20
# {'ltp': 21665.55, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 11 21
# {'ltp': 21666.1, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 11 22
# {'ltp': 21665.3, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 11 23
# {'ltp': 21665.9, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 11 24
# {'ltp': 21665.25, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 11 25
# {'ltp': 21664.85, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 11 26
# {'ltp': 21665.05, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 11 27
# {'ltp': 21664.4, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 11 28
# {'ltp': 21663.6, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 11 29
# {'ltp': 21663.45, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 11 30
# {'ltp': 21664.0, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 11 31
# {'ltp': 21663.75, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 11 32
# {'ltp': 21663.95, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 11 33
# {'ltp': 21663.05, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 11 34
# {'ltp': 21662.85, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 11 35
# {'ltp': 21661.85, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 11 36
# {'ltp': 21661.6, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 11 37
# {'ltp': 21661.5, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 11 38
# {'ltp': 21661.3, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 11 39
# {'ltp': 21660.95, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 11 40
# {'ltp': 21660.95, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 11 41
# {'ltp': 21661.7, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 11 42
# {'ltp': 21661.2, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 11 43
# {'ltp': 21661.5, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 11 44
# {'ltp': 21662.1, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 11 45
# {'ltp': 21662.15, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 11 46
# {'ltp': 21661.85, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 11 47
# {'ltp': 21662.85, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 11 48
# {'ltp': 21662.65, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 11 49
# {'ltp': 21661.65, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 11 50
# {'ltp': 21661.05, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 11 51
# {'ltp': 21661.65, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 11 52
# {'ltp': 21661.3, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 11 53
# {'ltp': 21661.1, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 11 54
# {'ltp': 21662.15, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 11 55
# {'ltp': 21661.0, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 11 56
# {'ltp': 21661.85, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 11 57
# {'ltp': 21660.85, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 11 58
# {'ltp': 21661.75, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 11 59
# {'ltp': 21661.6, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 12 0
# {'ltp': 21662.1, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 12 1
# {'ltp': 21662.65, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 12 2
# {'ltp': 21661.95, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 12 3
# {'ltp': 21662.2, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 12 4
# {'ltp': 21662.25, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 12 5
# {'ltp': 21661.85, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 12 6
# {'ltp': 21662.6, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 12 7
# {'ltp': 21662.65, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 12 8
# {'ltp': 21662.4, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 12 9
# {'ltp': 21661.8, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 12 10
# {'ltp': 21662.45, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 12 11
# {'ltp': 21663.35, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 12 12
# {'ltp': 21663.25, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 12 13
# {'ltp': 21662.7, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 12 14
# {'ltp': 21662.55, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 12 15
# {'ltp': 21662.6, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 12 16
# {'ltp': 21661.95, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 12 17
# {'ltp': 21661.4, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 12 18
# {'ltp': 21661.25, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 12 20
# {'ltp': 21661.85, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 12 21
# {'ltp': 21661.25, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 12 22
# {'ltp': 21659.7, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 12 23
# {'ltp': 21657.95, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 12 24
# {'ltp': 21658.5, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 12 25
# {'ltp': 21658.15, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 12 26
# {'ltp': 21659.0, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 12 27
# {'ltp': 21658.1, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 12 28
# {'ltp': 21659.0, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 12 29
# {'ltp': 21657.4, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 12 30
# {'ltp': 21658.15, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 12 31
# {'ltp': 21657.2, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 12 32
# {'ltp': 21657.0, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 12 33
# {'ltp': 21656.1, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 12 34
# {'ltp': 21655.0, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 12 35
# {'ltp': 21654.55, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 12 36
# {'ltp': 21655.2, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 12 37
# {'ltp': 21656.15, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 12 38
# {'ltp': 21656.25, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 12 39
# {'ltp': 21656.05, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 12 40
# {'ltp': 21656.45, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 12 41
# {'ltp': 21655.5, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 12 42
# {'ltp': 21655.25, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 12 43
# {'ltp': 21654.65, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 12 44
# {'ltp': 21655.2, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 12 45
# {'ltp': 21653.25, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 12 46
# {'ltp': 21652.3, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 12 47
# {'ltp': 21650.9, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 12 48
# {'ltp': 21651.7, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 12 49
# {'ltp': 21651.15, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 12 50
# {'ltp': 21649.05, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 12 51
# {'ltp': 21648.45, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 12 52
# {'ltp': 21647.5, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 12 53
# {'ltp': 21649.95, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 12 54
# {'ltp': 21648.95, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 12 55
# {'ltp': 21646.85, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 12 56
# {'ltp': 21648.45, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 12 57
# {'ltp': 21648.7, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 12 58
# {'ltp': 21649.35, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 12 59
# {'ltp': 21649.2, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 13 0
# {'ltp': 21648.85, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 13 1
# {'ltp': 21647.55, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 13 2
# {'ltp': 21649.1, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 13 3
# {'ltp': 21649.6, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 13 4
# {'ltp': 21647.95, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 13 5
# {'ltp': 21647.95, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 13 6
# {'ltp': 21648.0, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 13 7
# {'ltp': 21648.3, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 13 8
# {'ltp': 21648.9, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 13 9
# {'ltp': 21649.4, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 13 10
# {'ltp': 21649.8, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 13 11
# {'ltp': 21650.1, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 13 12
# {'ltp': 21651.45, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 13 13
# {'ltp': 21650.65, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 13 14
# {'ltp': 21651.35, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 13 15
# {'ltp': 21649.75, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 13 16
# {'ltp': 21649.0, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 13 17
# {'ltp': 21649.45, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 13 18
# {'ltp': 21649.75, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 13 19
# {'ltp': 21649.4, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 13 20
# {'ltp': 21650.15, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 13 21
# {'ltp': 21651.3, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 13 22
# {'ltp': 21651.1, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 13 23
# {'ltp': 21650.25, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 13 24
# {'ltp': 21651.1, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 13 25
# {'ltp': 21652.35, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 13 26
# {'ltp': 21650.0, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 13 27
# {'ltp': 21653.15, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 13 28
# {'ltp': 21652.1, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 13 29
# {'ltp': 21652.2, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 13 30
# {'ltp': 21652.45, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 13 31
# {'ltp': 21653.65, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 13 32
# {'ltp': 21653.2, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 13 33
# {'ltp': 21652.2, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 13 34
# {'ltp': 21653.55, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 13 35
# {'ltp': 21655.3, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 13 36
# {'ltp': 21655.8, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 13 37
# {'ltp': 21654.2, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 13 38
# {'ltp': 21655.65, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 13 39
# {'ltp': 21655.55, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 13 41
# {'ltp': 21655.8, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 13 42
# {'ltp': 21658.15, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 13 43
# {'ltp': 21659.0, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 13 44
# {'ltp': 21659.45, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 13 45
# {'ltp': 21659.75, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 13 46
# {'ltp': 21660.6, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 13 47
# {'ltp': 21658.9, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 13 48
# {'ltp': 21661.2, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 13 49
# {'ltp': 21659.25, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 13 50
# {'ltp': 21659.0, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 13 51
# {'ltp': 21660.55, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 13 52
# {'ltp': 21657.45, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 13 53
# {'ltp': 21657.45, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 13 54
# {'ltp': 21657.85, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 13 55
# {'ltp': 21657.7, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 13 56
# {'ltp': 21657.8, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 13 57
# {'ltp': 21657.15, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 13 58
# {'ltp': 21657.45, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 13 59
# {'ltp': 21656.6, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 14 0
# {'ltp': 21656.0, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 14 1
# {'ltp': 21656.7, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 14 2
# {'ltp': 21656.95, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 14 3
# {'ltp': 21656.85, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 14 4
# {'ltp': 21656.45, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 14 5
# {'ltp': 21655.4, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 14 6
# {'ltp': 21655.95, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 14 7
# {'ltp': 21656.95, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 14 8
# {'ltp': 21657.85, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 14 9
# {'ltp': 21658.8, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 14 10
# {'ltp': 21659.85, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 14 11
# {'ltp': 21659.85, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 14 12
# {'ltp': 21659.15, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 14 13
# {'ltp': 21660.8, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 14 14
# {'ltp': 21660.85, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 14 15
# {'ltp': 21660.45, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 14 16
# {'ltp': 21661.1, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 14 17
# {'ltp': 21660.7, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 14 18
# {'ltp': 21660.9, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 14 19
# {'ltp': 21661.15, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 14 20
# {'ltp': 21661.3, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 14 21
# {'ltp': 21660.6, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 14 22
# {'ltp': 21660.85, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 14 23
# {'ltp': 21661.35, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 14 24
# {'ltp': 21661.1, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 14 25
# {'ltp': 21660.5, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 14 26
# {'ltp': 21660.25, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 14 27
# {'ltp': 21660.15, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 14 28
# {'ltp': 21659.7, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 14 29
# {'ltp': 21660.6, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 14 30
# {'ltp': 21660.2, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 14 31
# {'ltp': 21660.4, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 14 32
# {'ltp': 21659.65, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 14 33
# {'ltp': 21661.0, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 14 34
# {'ltp': 21659.65, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 14 35
# {'ltp': 21661.3, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 14 36
# {'ltp': 21662.1, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 14 37
# {'ltp': 21661.75, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 14 38
# {'ltp': 21662.1, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 14 39
# {'ltp': 21661.45, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 14 40
# {'ltp': 21661.65, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 14 41
# {'ltp': 21661.85, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 14 42
# {'ltp': 21662.9, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 14 43
# {'ltp': 21663.95, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 14 44
# {'ltp': 21663.3, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 14 45
# {'ltp': 21663.3, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 14 46
# {'ltp': 21664.15, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 14 47
# {'ltp': 21663.7, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 14 48
# {'ltp': 21663.85, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 14 49
# {'ltp': 21663.5, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 14 50
# {'ltp': 21662.85, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 14 51
# {'ltp': 21663.05, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 14 52
# {'ltp': 21662.4, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 14 53
# {'ltp': 21663.25, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 14 54
# {'ltp': 21661.55, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 14 55
# {'ltp': 21661.85, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 14 56
# {'ltp': 21661.2, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 14 57
# {'ltp': 21661.95, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 14 58
# {'ltp': 21662.05, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 14 59
# {'ltp': 21662.05, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 15 0
# ready e!!!
#
# {'ltp': 21661.2, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 15 3
# {'ltp': 21660.3, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 15 4
# {'ltp': 21661.15, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 15 5
# {'ltp': 21661.6, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 15 6
# {'ltp': 21660.9, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 15 7
# {'ltp': 21661.75, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 15 8
# {'ltp': 21660.9, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 15 9
# {'ltp': 21661.55, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 15 10
# {'ltp': 21663.45, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 15 11
# {'ltp': 21662.05, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 15 12
# {'ltp': 21662.5, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 15 13
# {'ltp': 21662.5, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 15 14
# {'ltp': 21662.75, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 15 15
# {'ltp': 21662.05, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 15 16
# {'ltp': 21662.5, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 15 17
# {'ltp': 21662.3, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 15 18
# {'ltp': 21662.65, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 15 19
# {'ltp': 21661.95, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 15 20
# {'ltp': 21662.4, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 15 21
# {'ltp': 21661.8, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 15 22
# {'ltp': 21661.8, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 15 23
# {'ltp': 21661.8, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 15 24
# {'ltp': 21661.5, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 15 25
# {'ltp': 21661.2, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 15 26
# {'ltp': 21661.5, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 15 27
# {'ltp': 21661.95, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 15 28
# {'ltp': 21662.75, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 15 29
# {'ltp': 21662.75, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 15 30
# {'ltp': 21661.95, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 15 31
# {'ltp': 21661.4, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 15 32
# {'ltp': 21661.05, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 15 33
# {'ltp': 21661.7, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 15 34
# {'ltp': 21661.5, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 15 35
# {'ltp': 21662.3, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 15 36
# {'ltp': 21661.9, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 15 37
# {'ltp': 21661.1, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 15 38
# {'ltp': 21661.3, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 15 39
# {'ltp': 21662.15, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 15 40
# {'ltp': 21661.3, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 15 41
# {'ltp': 21661.05, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 15 42
# {'ltp': 21660.85, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 15 43
# {'ltp': 21660.5, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 15 44
# {'ltp': 21659.5, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 15 45
# {'ltp': 21658.35, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 15 46
# {'ltp': 21658.25, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 15 47
# {'ltp': 21659.1, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 15 48
# {'ltp': 21658.8, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 15 49
# {'ltp': 21659.0, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 15 50
# {'ltp': 21658.2, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 15 51
# {'ltp': 21658.45, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 15 52
# {'ltp': 21658.8, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 15 53
# {'ltp': 21659.4, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 15 54
# {'ltp': 21659.8, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 15 55
# {'ltp': 21660.3, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 15 56
# {'ltp': 21660.35, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 15 57
# {'ltp': 21660.0, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 15 58
# {'ltp': 21660.35, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 15 59
# {'ltp': 21660.85, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 16 0
# {'ltp': 21662.1, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 16 1
# {'ltp': 21661.15, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 16 2
# {'ltp': 21661.2, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 16 3
# {'ltp': 21662.05, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 16 4
# {'ltp': 21662.0, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 16 5
# {'ltp': 21662.8, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 16 6
# {'ltp': 21662.6, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 16 7
# {'ltp': 21662.7, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 16 8
# {'ltp': 21662.75, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 16 9
# {'ltp': 21663.7, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 16 10
# {'ltp': 21664.05, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 16 11
# {'ltp': 21664.4, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 16 12
# {'ltp': 21663.15, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 16 13
# {'ltp': 21663.95, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 16 14
# {'ltp': 21665.65, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 16 15
# {'ltp': 21666.35, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 16 16
# {'ltp': 21667.0, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 16 17
# {'ltp': 21668.5, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 16 18
# {'ltp': 21668.25, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 16 19
# {'ltp': 21668.6, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 16 21
# {'ltp': 21668.75, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 16 22
# {'ltp': 21667.4, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 16 23
# {'ltp': 21666.7, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 16 24
# {'ltp': 21667.8, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 16 25
# {'ltp': 21667.65, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 16 26
# {'ltp': 21667.55, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 16 27
# {'ltp': 21666.9, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 16 28
# {'ltp': 21666.45, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 16 29
# {'ltp': 21666.75, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 16 30
# {'ltp': 21666.25, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 16 31
# {'ltp': 21666.1, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 16 32
# {'ltp': 21665.95, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 16 33
# {'ltp': 21665.85, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 16 34
# {'ltp': 21666.25, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 16 35
# {'ltp': 21665.75, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 16 36
# {'ltp': 21666.85, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 16 37
# {'ltp': 21665.9, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 16 38
# {'ltp': 21666.15, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 16 39
# {'ltp': 21666.7, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 16 40
# {'ltp': 21667.0, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 16 41
# {'ltp': 21666.4, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 16 42
# {'ltp': 21666.0, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 16 43
# {'ltp': 21665.7, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 16 44
# {'ltp': 21666.55, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 16 45
# {'ltp': 21666.95, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 16 46
# {'ltp': 21666.9, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 16 47
# {'ltp': 21667.3, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 16 48
# {'ltp': 21667.25, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 16 49
# {'ltp': 21667.4, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 16 50
# {'ltp': 21666.8, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 16 51
# {'ltp': 21665.8, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 16 52
# {'ltp': 21666.2, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 16 53
# {'ltp': 21666.2, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 16 54
# {'ltp': 21666.3, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 16 55
# {'ltp': 21665.9, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 16 56
# {'ltp': 21665.65, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 16 57
# {'ltp': 21663.05, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 16 58
# {'ltp': 21664.25, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 16 59
# {'ltp': 21664.15, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 17 0
# {'ltp': 21663.0, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 17 1
# {'ltp': 21662.15, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 17 2
# {'ltp': 21662.05, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 17 3
# {'ltp': 21661.4, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 17 4
# {'ltp': 21660.65, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 17 5
# {'ltp': 21661.55, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 17 6
# {'ltp': 21660.95, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 17 7
# {'ltp': 21660.15, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 17 8
# {'ltp': 21660.8, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 17 9
# {'ltp': 21660.5, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 17 10
# {'ltp': 21660.4, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 17 11
# {'ltp': 21659.8, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 17 12
# {'ltp': 21658.85, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 17 13
# {'ltp': 21659.45, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 17 14
# {'ltp': 21659.65, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 17 15
# {'ltp': 21659.85, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 17 16
# {'ltp': 21659.85, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 17 17
# {'ltp': 21659.4, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 17 18
# {'ltp': 21659.0, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 17 19
# {'ltp': 21659.05, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 17 20
# {'ltp': 21658.4, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 17 21
# {'ltp': 21658.95, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  10 17 22
# ...
# {'ltp': 21665.6, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  14 15 7
# {'ltp': 21664.25, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  14 15 8
# {'ltp': 21664.05, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  14 15 9
# {'ltp': 21664.55, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  14 15 11
# {'ltp': 21664.2, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  14 15 12
# {'ltp': 21663.7, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  14 15 13
# {'ltp': 21663.75, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  14 15 14
# {'ltp': 21664.4, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  14 15 15
# {'ltp': 21663.95, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  14 15 16
# {'ltp': 21664.4, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  14 15 17
# {'ltp': 21664.1, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  14 15 19
# {'ltp': 21664.15, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  14 15 20
# {'ltp': 21664.65, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  14 15 21
# {'ltp': 21665.2, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  14 15 23
# {'ltp': 21666.0, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  14 15 24
# {'ltp': 21665.5, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  14 15 25
# {'ltp': 21664.8, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  14 15 26
# {'ltp': 21666.4, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  14 15 27
# {'ltp': 21666.25, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  14 15 29
# {'ltp': 21668.05, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  14 15 30
# {'ltp': 21666.55, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  14 15 31
# {'ltp': 21667.35, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  14 15 32
# {'ltp': 21666.2, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  14 15 33
# {'ltp': 21666.55, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  14 15 34
# {'ltp': 21667.85, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  14 15 36
# {'ltp': 21666.6, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  14 15 37
# {'ltp': 21667.1, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  14 15 38
# {'ltp': 21668.15, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  14 15 39
# {'ltp': 21667.45, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  14 15 40
# {'ltp': 21667.15, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  14 15 41
# {'ltp': 21667.3, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  14 15 42
# {'ltp': 21667.65, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  14 15 44
# {'ltp': 21667.15, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  14 15 45
# {'ltp': 21666.65, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  14 15 46
# {'ltp': 21666.8, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  14 15 47
# {'ltp': 21666.25, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  14 15 48
# {'ltp': 21666.35, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  14 15 49
# {'ltp': 21666.8, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  14 15 50
# {'ltp': 21667.05, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  14 15 51
# {'ltp': 21667.0, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  14 15 53
# {'ltp': 21667.4, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  14 15 54
# {'ltp': 21666.45, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  14 15 55
# {'ltp': 21667.25, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  14 15 56
# {'ltp': 21668.0, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  14 15 57
# {'ltp': 21668.35, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  14 15 58
# {'ltp': 21667.85, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  14 15 59
# {'ltp': 21667.0, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  14 16 1
# {'ltp': 21667.85, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  14 16 2
# {'ltp': 21667.3, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  14 16 3
# {'ltp': 21666.75, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  14 16 4
# {'ltp': 21666.15, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  14 16 5
# {'ltp': 21666.1, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  14 16 6
# {'ltp': 21665.45, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  14 16 8
# {'ltp': 21664.3, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  14 16 9
# {'ltp': 21665.75, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  14 16 10
# {'ltp': 21663.35, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  14 16 11
# {'ltp': 21663.15, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  14 16 12
# {'ltp': 21664.65, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  14 16 13
# {'ltp': 21663.25, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  14 16 15
# {'ltp': 21662.05, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  14 16 16
# {'ltp': 21663.7, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  14 16 17
# {'ltp': 21661.45, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  14 16 18
# {'ltp': 21662.35, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  14 16 19
# {'ltp': 21663.75, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  14 16 20
# {'ltp': 21662.4, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  14 16 22
# {'ltp': 21662.1, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  14 16 23
# {'ltp': 21662.75, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  14 16 24
# {'ltp': 21664.6, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  14 16 25
# {'ltp': 21663.4, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  14 16 26
# {'ltp': 21663.95, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  14 16 27
# {'ltp': 21664.4, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  14 16 29
# {'ltp': 21663.65, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  14 16 30
# {'ltp': 21665.0, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  14 16 31
# {'ltp': 21665.0, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  14 16 32
# {'ltp': 21663.6, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  14 16 33
# {'ltp': 21663.3, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  14 16 34
# {'ltp': 21663.0, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  14 16 35
# {'ltp': 21663.0, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  14 16 37
# {'ltp': 21662.1, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  14 16 38
# {'ltp': 21661.9, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  14 16 39
# {'ltp': 21662.55, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  14 16 40
# {'ltp': 21661.9, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  14 16 41
# {'ltp': 21662.35, 'symbol': 'NSE:NIFTY50-INDEX', 'type': 'if'} 	time:  14 16 42
# {'type': 'unsub', 'code': 200, 'message': 'Unsubscribed', 's': 'ok'} 	time:  14 16 44
# Error: KeyError: The key 'symbol' is missing in the response.
# {'type': 'unsub', 'code': 200, 'message': 'Unsubscribed', 's': 'ok'} 	time:  14 16 45
# Error: KeyError: The key 'symbol' is missing in the response.
# {'type': 'unsub', 'code': 200, 'message': 'Unsubscribed', 's': 'ok'} 	time:  14 16 46
# Error: KeyError: The key 'symbol' is missing in the response.
# {'type': 'unsub', 'code': 200, 'message': 'Unsubscribed', 's': 'ok'} 	time:  14 16 47
# Error: KeyError: The key 'symbol' is missing in the response.
# {'type': 'unsub', 'code': 200, 'message': 'Unsubscribed', 's': 'ok'} 	time:  14 16 48
# Error: KeyError: The key 'symbol' is missing in the response.
# {'type': 'unsub', 'code': 200, 'message': 'Unsubscribed', 's': 'ok'} 	time:  14 16 49
# Error: KeyError: The key 'symbol' is missing in the response.
# {'type': 'unsub', 'code': 200, 'message': 'Unsubscribed', 's': 'ok'} 	time:  14 16 50
# Error: KeyError: The key 'symbol' is missing in the response.
# {'type': 'unsub', 'code': 200, 'message': 'Unsubscribed', 's': 'ok'} 	time:  14 16 51
# Error: KeyError: The key 'symbol' is missing in the response.
# {'type': 'unsub', 'code': 200, 'message': 'Unsubscribed', 's': 'ok'} 	time:  14 16 52
# Error: KeyError: The key 'symbol' is missing in the response.
# {'type': 'unsub', 'code': 200, 'message': 'Unsubscribed', 's': 'ok'} 	time:  14 16 53
# Error: KeyError: The key 'symbol' is missing in the response.
# {'type': 'unsub', 'code': 200, 'message': 'Unsubscribed', 's': 'ok'} 	time:  14 16 54
# Error: KeyError: The key 'symbol' is missing in the response.
# {'type': 'unsub', 'code': 200, 'message': 'Unsubscribed', 's': 'ok'} 	time:  14 16 55
# Error: KeyError: The key 'symbol' is missing in the response.
# {'type': 'unsub', 'code': 200, 'message': 'Unsubscribed', 's': 'ok'} 	time:  14 16 56
# Error: KeyError: The key 'symbol' is missing in the response.
# {'type': 'unsub', 'code': 200, 'message': 'Unsubscribed', 's': 'ok'} 	time:  14 16 57
# Error: KeyError: The key 'symbol' is missing in the response.
# {'type': 'unsub', 'code': 200, 'message': 'Unsubscribed', 's': 'ok'} 	time:  14 16 58
# Error: KeyError: The key 'symbol' is missing in the response.
# {'type': 'unsub', 'code': 200, 'message': 'Unsubscribed', 's': 'ok'} 	time:  14 16 59
# Error: KeyError: The key 'symbol' is missing in the response.
# {'type': 'unsub', 'code': 200, 'message': 'Unsubscribed', 's': 'ok'} 	time:  14 17 0
# Error: KeyError: The key 'symbol' is missing in the response.
# {'type': 'unsub', 'code': 200, 'message': 'Unsubscribed', 's': 'ok'} 	time:  14 17 1
# Error: KeyError: The key 'symbol' is missing in the response.
# {'type': 'unsub', 'code': 200, 'message': 'Unsubscribed', 's': 'ok'} 	time:  14 17 2
# Error: KeyError: The key 'symbol' is missing in the response.
# {'type': 'unsub', 'code': 200, 'message': 'Unsubscribed', 's': 'ok'} 	time:  14 17 3
# Error: KeyError: The key 'symbol' is missing in the response.
# {'type': 'unsub', 'code': 200, 'message': 'Unsubscribed', 's': 'ok'} 	time:  14 17 4
# Error: KeyError: The key 'symbol' is missing in the response.
# {'type': 'unsub', 'code': 200, 'message': 'Unsubscribed', 's': 'ok'} 	time:  14 17 5
# Error: KeyError: The key 'symbol' is missing in the response.
# {'type': 'unsub', 'code': 200, 'message': 'Unsubscribed', 's': 'ok'} 	time:  14 17 6
# Error: KeyError: The key 'symbol' is missing in the response.
# {'type': 'unsub', 'code': 200, 'message': 'Unsubscribed', 's': 'ok'} 	time:  14 17 7
# Error: KeyError: The key 'symbol' is missing in the response.
# {'type': 'unsub', 'code': 200, 'message': 'Unsubscribed', 's': 'ok'} 	time:  14 17 8
# Error: KeyError: The key 'symbol' is missing in the response.
# {'type': 'unsub', 'code': 200, 'message': 'Unsubscribed', 's': 'ok'} 	time:  14 17 9
# Error: KeyError: The key 'symbol' is missing in the response.
# {'type': 'unsub', 'code': 200, 'message': 'Unsubscribed', 's': 'ok'} 	time:  14 17 10
# Error: KeyError: The key 'symbol' is missing in the response.
# {'type': 'unsub', 'code': 200, 'message': 'Unsubscribed', 's': 'ok'} 	time:  14 17 11
# Error: KeyError: The key 'symbol' is missing in the response.
# {'type': 'unsub', 'code': 200, 'message': 'Unsubscribed', 's': 'ok'} 	time:  14 17 12
# Error: KeyError: The key 'symbol' is missing in the response.
# {'type': 'unsub', 'code': 200, 'message': 'Unsubscribed', 's': 'ok'} 	time:  14 17 13
# Error: KeyError: The key 'symbol' is missing in the response.
# {'type': 'unsub', 'code': 200, 'message': 'Unsubscribed', 's': 'ok'} 	time:  14 17 14
# Error: KeyError: The key 'symbol' is missing in the response.
# {'type': 'unsub', 'code': 200, 'message': 'Unsubscribed', 's': 'ok'} 	time:  14 17 15
# Error: KeyError: The key 'symbol' is missing in the response.
# {'type': 'unsub', 'code': 200, 'message': 'Unsubscribed', 's': 'ok'} 	time:  14 17 16
# Error: KeyError: The key 'symbol' is missing in the response.
# {'type': 'unsub', 'code': 200, 'message': 'Unsubscribed', 's': 'ok'} 	time:  14 17 17
# Error: KeyError: The key 'symbol' is missing in the response.
# {'type': 'unsub', 'code': 200, 'message': 'Unsubscribed', 's': 'ok'} 	time:  14 17 18
# Error: KeyError: The key 'symbol' is missing in the response.
# {'type': 'unsub', 'code': 200, 'message': 'Unsubscribed', 's': 'ok'} 	time:  14 17 19
# Error: KeyError: The key 'symbol' is missing in the response.
# {'type': 'unsub', 'code': 200, 'message': 'Unsubscribed', 's': 'ok'} 	time:  14 17 20
# Error: KeyError: The key 'symbol' is missing in the response.
# {'type': 'unsub', 'code': 200, 'message': 'Unsubscribed', 's': 'ok'} 	time:  14 17 21
# Error: KeyError: The key 'symbol' is missing in the response.
# {'type': 'unsub', 'code': 200, 'message': 'Unsubscribed', 's': 'ok'} 	time:  14 17 22
# Error: KeyError: The key 'symbol' is missing in the response.
# {'type': 'unsub', 'code': 200, 'message': 'Unsubscribed', 's': 'ok'} 	time:  14 17 23
# Error: KeyError: The key 'symbol' is missing in the response.
# {'type': 'unsub', 'code': 200, 'message': 'Unsubscribed', 's': 'ok'} 	time:  14 17 24
# Error: KeyError: The key 'symbol' is missing in the response.
# {'type': 'unsub', 'code': 200, 'message': 'Unsubscribed', 's': 'ok'} 	time:  14 17 25
# Error: KeyError: The key 'symbol' is missing in the response.
# {'type': 'unsub', 'code': 200, 'message': 'Unsubscribed', 's': 'ok'} 	time:  14 17 26
# Error: KeyError: The key 'symbol' is missing in the response.
# {'type': 'unsub', 'code': 200, 'message': 'Unsubscribed', 's': 'ok'} 	time:  14 17 27
# Error: KeyError: The key 'symbol' is missing in the response.
# {'type': 'unsub', 'code': 200, 'message': 'Unsubscribed', 's': 'ok'} 	time:  14 17 28
# Error: KeyError: The key 'symbol' is missing in the response.
# {'type': 'unsub', 'code': 200, 'message': 'Unsubscribed', 's': 'ok'} 	time:  14 17 29
# Error: KeyError: The key 'symbol' is missing in the response.
# {'type': 'unsub', 'code': 200, 'message': 'Unsubscribed', 's': 'ok'} 	time:  14 17 30
# Error: KeyError: The key 'symbol' is missing in the response.
# {'type': 'unsub', 'code': 200, 'message': 'Unsubscribed', 's': 'ok'} 	time:  14 17 31
# Error: KeyError: The key 'symbol' is missing in the response.
# {'type': 'unsub', 'code': 200, 'message': 'Unsubscribed', 's': 'ok'} 	time:  14 17 32
# Error: KeyError: The key 'symbol' is missing in the response.
# {'type': 'unsub', 'code': 200, 'message': 'Unsubscribed', 's': 'ok'} 	time:  14 17 33
# Error: KeyError: The key 'symbol' is missing in the response.
# {'type': 'unsub', 'code': 200, 'message': 'Unsubscribed', 's': 'ok'} 	time:  14 17 34
# Error: KeyError: The key 'symbol' is missing in the response.
# {'type': 'unsub', 'code': 200, 'message': 'Unsubscribed', 's': 'ok'} 	time:  14 17 35
# Error: KeyError: The key 'symbol' is missing in the response.
# {'type': 'unsub', 'code': 200, 'message': 'Unsubscribed', 's': 'ok'} 	time:  14 17 36
# Error: KeyError: The key 'symbol' is missing in the response.
# {'type': 'unsub', 'code': 200, 'message': 'Unsubscribed', 's': 'ok'} 	time:  14 17 37
# Error: KeyError: The key 'symbol' is missing in the response.
# {'type': 'unsub', 'code': 200, 'message': 'Unsubscribed', 's': 'ok'} 	time:  14 17 38
# Error: KeyError: The key 'symbol' is missing in the response.
# {'type': 'unsub', 'code': 200, 'message': 'Unsubscribed', 's': 'ok'} 	time:  14 17 39
# Error: KeyError: The key 'symbol' is missing in the response.
# {'type': 'unsub', 'code': 200, 'message': 'Unsubscribed', 's': 'ok'} 	time:  14 17 40
# Error: KeyError: The key 'symbol' is missing in the response.
# {'type': 'unsub', 'code': 200, 'message': 'Unsubscribed', 's': 'ok'} 	time:  14 17 41
# Error: KeyError: The key 'symbol' is missing in the response.
# {'type': 'unsub', 'code': 200, 'message': 'Unsubscribed', 's': 'ok'} 	time:  14 17 42
# Error: KeyError: The key 'symbol' is missing in the response.
# {'type': 'unsub', 'code': 200, 'message': 'Unsubscribed', 's': 'ok'} 	time:  14 17 43
# Error: KeyError: The key 'symbol' is missing in the response.
# {'type': 'unsub', 'code': 200, 'message': 'Unsubscribed', 's': 'ok'} 	time:  14 17 44
# Error: KeyError: The key 'symbol' is missing in the response.
# {'type': 'unsub', 'code': 200, 'message': 'Unsubscribed', 's': 'ok'} 	time:  14 17 45
# Error: KeyError: The key 'symbol' is missing in the response.
# {'type': 'unsub', 'code': 200, 'message': 'Unsubscribed', 's': 'ok'} 	time:  14 17 46
# Error: KeyError: The key 'symbol' is missing in the response.
# {'type': 'unsub', 'code': 200, 'message': 'Unsubscribed', 's': 'ok'} 	time:  14 17 47
