# %%
from fyers_apiv3 import fyersModel
from fyers_apiv3.FyersWebsocket import data_ws

import pandas as pd
import numpy as np
import math

import datetime as dt
from datetime import date, timedelta,datetime
import time 

from fyers_apiv3.FyersWebsocket import data_ws
import csv

import matplotlib.pyplot as plt
import mplfinance as mpf

import scipy

from  time import sleep
import threading
import os
import pyotp
import requests
import json
import pytz
from urllib.parse import parse_qs,urlparse
import base64

import warnings
pd.set_option('display.max_columns', None)
warnings.filterwarnings('ignore')

# %%
redirect_uri = "https://trade.fyers.in/api-login/redirect-uri/index.html"
client_id='HTHFWXFS49-100'
secret_key = 'JOQVVTY9UJ'
FY_ID = "YB00632"  
TOTP_KEY = "3Y7PAJSPNHXEADGRDD726MLHJW43AJGH"  
PIN = "1964" 

grant_type = "authorization_code"                  
response_type = "code"                         
state = "sample"                                  

appSession = fyersModel.SessionModel(client_id = client_id, redirect_uri = redirect_uri,response_type=response_type,state=state,secret_key=secret_key,grant_type=grant_type)


generateTokenUrl = appSession.generate_authcode()
generateTokenUrl


def getEncodedString(string):
    string = str(string)
    base64_bytes = base64.b64encode(string.encode("ascii"))
    return base64_bytes.decode("ascii")
  



URL_SEND_LOGIN_OTP="https://api-t2.fyers.in/vagator/v2/send_login_otp_v2"
res = requests.post(url=URL_SEND_LOGIN_OTP, json={"fy_id":getEncodedString(FY_ID),"app_id":"2"}).json()   
print(res) 

if datetime.now().second % 30 > 27 : sleep(5)
URL_VERIFY_OTP="https://api-t2.fyers.in/vagator/v2/verify_otp"
res2 = requests.post(url=URL_VERIFY_OTP, json= {"request_key":res["request_key"],"otp":pyotp.TOTP(TOTP_KEY).now()}).json()  
print(res2) 


ses = requests.Session()
URL_VERIFY_OTP2="https://api-t2.fyers.in/vagator/v2/verify_pin_v2"
payload2 = {"request_key": res2["request_key"],"identity_type":"pin","identifier":getEncodedString(PIN)}
res3 = ses.post(url=URL_VERIFY_OTP2, json= payload2).json()  
print(res3) 


ses.headers.update({
    'authorization': f"Bearer {res3['data']['access_token']}"
})


TOKENURL="https://api-t1.fyers.in/api/v3/token"
payload3 = {"fyers_id":FY_ID,
           "app_id":client_id[:-4],
           "redirect_uri":redirect_uri,
           "appType":"100","code_challenge":"",
           "state":"None","scope":"","nonce":"","response_type":"code","create_cookie":True}

res3 = ses.post(url=TOKENURL, json= payload3).json()  
print(res3)


url = res3['Url']
print(url)
parsed = urlparse(url)
auth_code = parse_qs(parsed.query)['auth_code'][0]
auth_code


grant_type = "authorization_code" 

response_type = "code"  

session = fyersModel.SessionModel(
    client_id=client_id,
    secret_key=secret_key, 
    redirect_uri=redirect_uri, 
    response_type=response_type, 
    grant_type=grant_type
)

session.set_token(auth_code)

response = session.generate_token()

#print(response)

access_token = response['access_token']

fyers = fyersModel.FyersModel(client_id=client_id, is_async=False, token=access_token, log_path=os.getcwd())
fyers.get_profile()
# Out:
# {'s': 'ok', 'code': 1043, 'client_name': 'Baban Maruti Pawar', 'nick_name': 'Baban', 'pin_created': True, 'totp_enabled': True, 'avatar_link': None, 'message': 'user exist', 'mobile_no': '89xxxxxx82', 'email_id': 'bxxxxxxxxxxxx5@gmail.com', 'request_key': 'eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9..BWuYif6lqCMQJ1UYWtxL-rupdCCX-ltFbBWBi5vxdMA'}
# {'s': 'ok', 'code': 2, 'request_key': 'eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJpYXQiOjE3MDQxNzAyMjMsImV4cCI6MTcwNDI1NjYyMywibmJmIjoxNzA0MTcwMjIzLCJmeV9pZCI6IllCMDA2MzIiLCJyZXF1ZXN0X2tleSI6IkdESTFDVXY1bmZ2aUxhWlNIUTlTRkVLdnV0VE1UVG5TRnZUR0VRTENVcGJNRVYyM0xMIn0.MfU1B-52YiXK7jYLKBDy5WolzfBTQC9Njnuia9HQPT0', 'client_name': 'Baban Maruti Pawar', 'nick_name': 'Baban', 'pin_created': True, 'message': 'fy_id and OTP verified successfully'}
# {'s': 'ok', 'code': 1004, 'message': 'Pin is Verified', 'data': {'refresh_token': 'eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.....Zhxoy_ALbsMNmbo1AKtp5gMSydC2oeRKaM4yvDTdyIs', 'access_token': 'eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.....Z90p_YTU4JHffPeFnKbgAxIDYLL1Fl5DhWCCHpJ9gVo'}}
# {'s': 'ok', 'code': 308, 'message': '', 'cookie': '_FYERS=eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9..v8B_ZKjYBUvlW-ggKuj56JB6wEileYoeZvzb8xuxiPY', 'Url': 'https://trade.fyers.in/api-login/redirect-uri/index.html?s=ok&code=200&auth_code=eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.....k6LVhaiLDGTTGtC8BgvIl2xVlY6uueu5Q6WVAtUQfXY&state=None'}
# https://trade.fyers.in/api-login/redirect-uri/index.html?s=ok&code=200&auth_code=eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.....k6LVhaiLDGTTGtC8BgvIl2xVlY6uueu5Q6WVAtUQfXY&state=None
# {'s': 'ok',
#  'code': 200,
#  'message': '',
#  'data': {'fy_id': 'YB00632',
#   'name': 'BABAN MARUTI PAWAR',
#   'image': None,
#   'display_name': None,
#   'pin_change_date': '21-12-2023 21:01:26',
#   'email_id': 'babanpawar8975@gmail.com',
#   'pwd_change_date': None,
#   'PAN': '---------',
#   'mobile_number': '8975963982',
#   'totp': True,
#   'pwd_to_expire': 90}}

# %%
start_date = date.today()
end_date = date.today()
print("Start Date:", start_date)
print("End Date:", end_date)
# Out:
# Start Date: 2024-01-02
# End Date: 2024-01-02

# %% [markdown]
# stdate_str = input("Enter the previous active market date (YYYY-MM-DD): ")

# %%
csv_file_path = 'today_BN_lvls.csv'

# Create an empty list to store values from column N
lvl = []

# Open the CSV file
with open(csv_file_path, 'r') as file:
    # Create a CSV reader object using DictReader
    csv_reader = csv.DictReader(file)

    # Iterate over the rows in the CSV file
    for row in csv_reader:
        # Assuming 'N' is the header for the column
        # Append the value from column 'N' to the list
        lvl.append(float(row['BN']))

# Now, 'column_n_values' contains all the values from column 'N'
print("lvl:", lvl)
# Out:
# lvl: [48449.0, 48348.0, 48221.0, 48081.0, 47937.0, 47807.0]

# %%
historydata = pd.DataFrame()

# %%
def gethistorydata(st,ed,res):
    data = {
            "symbol":"NSE:NIFTYBANK-INDEX",
            "resolution":str(res),
            "date_format":"1",
            "range_from":start_date,
            "range_to":end_date,
            "cont_flag":"0"
            }
    global historydata
    repo = fyers.history(data=data)
    #print(repo)
    data = pd.DataFrame.from_dict(repo['candles'])
    #global cols
    cols = ['datetime', 'open', 'high','low','close', 'volume']
    data.columns = cols
    
    data['datetime'] = pd.to_datetime(data['datetime'],unit="s")
    data['datetime'] = data['datetime'].dt.tz_localize('utc').dt.tz_convert('Asia/Kolkata')
    
    #data = data.set_index('datetime')
    historydata = data
    historydata['datetime'] = pd.to_datetime(historydata['datetime'])
    historydata.set_index('datetime', inplace=True)

#     historydata['date'] = historydata['datetime'].dt.date
# #     historydata.set_index('date', inplace=True)
#     historydata['time'] = historydata['datetime'].dt.time

#     historydata.drop(columns=['datetime'], inplace=True)
    historydata.drop(columns=['volume'], inplace=True)
    
    #append(historydata,data)],axis=0)
    #historydata.to_csv("75op.csv")
#     print(historydata)

# %%
gethistorydata(start_date,end_date,5)

# %%
def pointchecker(pt,rg):
    point_value = pt
    
    for level in lvl:
        if abs(point_value - level) <= rg:
            return True
    else:
            return False

# %%
def plot_tolerance_range(level, arr, tolerance=30, color='lightblue', alpha=0.3):
    lower_bound = level - tolerance
    upper_bound = level + tolerance
    plt.fill_between(range(len(arr)), lower_bound, upper_bound, color=color, alpha=alpha,label='level range')

# %%
global historydata

sl=0
target=0
rrr = 0

ready=0
count=0
status =0
tobs = 0

# %%
def plot_candles():
    mpf.plot(historydata, type='candle', style='yahoo', title='Candlestick Chart', ylabel='Price', hlines=lvl)

# %%
def count_candles(df, start_candle_value_high, start_candle_value_low, end_candle_value_high, end_candle_value_low, candle_value_column1="high", candle_value_column2="low"):
    counts = 0
    
    for index, row in df.iterrows():
        candle_high = row[candle_value_column1]
        candle_low = row[candle_value_column2]
        
        if(start_candle_value_high > candle_high and start_candle_value_low < candle_low):
            counts += 1
        else:
            count=0
            break
            
    return counts

# %%
def find_closest_level(point, levels, direction='upward'):
    closest_level = None
    min_distance = float('inf')

    for level in levels:
        distance = abs(level - point)

        if direction == 'upward' and level > point:
            if distance < min_distance:
                min_distance = distance
                closest_level = level
        elif direction == 'downward' and level < point:
            if distance < min_distance:
                min_distance = distance
                closest_level = level

    return closest_level

# %%
def count_back_to_back_within_range(dataframe, column_name, target_value, margin):
    if len(dataframe) < 2:
        return 0

    # Iterate over rows to check back-to-back condition
    count_of_back_to_back = 0
    for i in range(1, len(dataframe)):
        current_value = dataframe[column_name].iloc[i]
        previous_value = dataframe[column_name].iloc[i - 1]

        # Check if current and previous values are within the specified range
        if (current_value >= target_value - margin) and (current_value <= target_value + margin) and \
           (previous_value >= target_value - margin) and (previous_value <= target_value + margin):
            count_of_back_to_back += 1

    return count_of_back_to_back

# %% [raw]
# count_candles(historydata, historydata['high'].iloc[0],historydata['low'].iloc[0], historydata['high'].iloc[11], historydata['low'].iloc[11])

# %%
global historydata
itr=0
secitr=0
  
neck=0
extra=0
midline=0
sl=0
target=0
rrr = 0

ready=0
count=0
status =0
tobs = 0
secitr=0
point1=0
point2=0
c=0
c1=0

# %%
def onmessage(message):
    print(message,"\ttime: ",time.localtime().tm_hour,time.localtime().tm_min,time.localtime().tm_sec)
    time.sleep(1)
    
    global historydata,itr,sl,target,rrr,ready,count,status,tobs,secitr,point1,point2,c,c1
    
    t = time.localtime()
    cmin = time.strftime("%M", t)
    csec = time.strftime("%S", t)  
#     global tops,bottoms,arr

    if(ready==1 and itr==1):
        c1= count_candles(historydata, historydata['high'].iloc[0],historydata['low'].iloc[0], historydata['high'].iloc[-1], historydata['low'].iloc[-1])
        if (c == c1 and c!=0 and c1!=0 and ((message['ltp'] <= (point1 + 5) and message['ltp'] >= (point1 - 5)) or (message['ltp'] <= (point2 + 5) and message['ltp'] >= (point2 - 5)))):
            print("entry made on: ",message['ltp'])
            entryprice = message['ltp']
            entryhour = time.localtime(time.time()).tm_hour
            entrymin =  time.localtime(time.time()).tm_min
            entrydate = date.today()
            count = count+1
            status = 1
            ready=0
            secitr=1
            start_time = time.time()

    if (int(cmin) % 5 == 0 and int(csec)==1):

        gethistorydata(start_date,end_date,5)  
        plot_candles()
        
        point1 = historydata['high'].iloc[0]
        point2 = historydata['low'].iloc[0]
        
        if(historydata['close'].iloc[-1]>point1 and historydata['close'].iloc[-2]<=point1):
            c= count_candles(historydata, historydata['high'].iloc[0],historydata['low'].iloc[0], historydata['high'].iloc[-1], historydata['low'].iloc[-1])
            if(c>2):
                for i in lvl:
                    if(i<point1 and i>point1-60):
                        sl = i
                        
                    else:
                        sl = point1-60
                        
                target = find_closest_level(point1,lvl) -30
                rrr = (abs(target-point1))/(point1-sl)
                ready=1
                print("\nready e!!!\n")
                            
        elif(historydata['close'].iloc[-1]<point2 and historydata['close'].iloc[-2]>=point2):
            c= count_candles(historydata, historydata['high'].iloc[0],historydata['low'].iloc[0], historydata['high'].iloc[-1], historydata['low'].iloc[-1])
            if(c>2):
                for i in lvl:
                    if(i>point2 and i<point2+60):
                        sl = i
                    else:
                        sl = point2+60
                        
                target = find_closest_level(point1,lvl,direction='downward') + 30
                rrr = (abs(point2-target))/(sl-point2)
                ready=1
                print("\nready e!!!\n")
        

    if(secitr == 0 and ready == 1 and rrr>=0.6 and count<1):
        if(c>2):                
            itr=itr+1
        if (c > 2 and 
        (point1 < historydata['close'].iloc[-1] <= (point1 + 10)) or 
        (point2 - 10) <= historydata['close'].iloc[-1] < point2):

            print("entry made on: ",message['ltp'])
            entryprice = message['ltp']
            entryhour = time.localtime(time.time()).tm_hour
            entrymin =  time.localtime(time.time()).tm_min
            entrydate = date.today()
            count = count+1
            status = 1
            start_time = time.time()

        
    elif(target!=0 and sl!=0 and status==1 and ((message['ltp']>=target or message['ltp']<=sl) or pointchecker(message['ltp'],30)==True)):
        print("entry exited on: ",message['ltp'])
        exitprice = message['ltp']
        status = 0
        ready=0


        with open('ic_backtest_report.csv', 'a', newline='') as csvfile:
            writer = csv.writer(csvfile)
            exitprice = message['ltp']
            exithour = time.localtime(time.time()).tm_hour
            exitmin =  time.localtime(time.time()).tm_min       #historydata.iloc[-1]['time']
            exitdate = date.today()
            pandl = entryprice-exitprice
            new_row = [symbols[0],entrydate,entryhour,entrymin,entryprice,exitdate,exithour,exitmin,exitprice,pandl]
            writer.writerow(new_row)
            print("exported trade data")

        if(message['symbol']=='NSE:NIFTYBANK-INDEX' and count>=2):
            data_type= "SymbolUpdate"
            symbol_to_unsubscribe= ['NSE:NIFTYBANK-INDEX']
            wfyers.unsubscribe(symbols= symbol_to_unsubscribe, data_type = data_type)
            print("unsubscribed") 
        
    elif(status==1):
#         while True:
        current_time = time.time()
        elapsed_minutes = int((current_time - start_time) / 60)
        remaining_minutes = target_minutes - elapsed_minutes

        if(remaining_minutes <= 0 ):
            print("entry exited on: ",message['ltp'])
            exitprice = message['ltp']
            status = 0
            ready=0


            with open('ic_backtest_report.csv', 'a', newline='') as csvfile:
                writer = csv.writer(csvfile)
                exitprice = message['ltp']
                exithour = time.localtime(time.time()).tm_hour
                exitmin =  time.localtime(time.time()).tm_min       #historydata.iloc[-1]['time']
                exitdate = date.today()
                pandl = entryprice-exitprice
                new_row = [symbols[0],entrydate,entryhour,entrymin,entryprice,exitdate,exithour,exitmin,exitprice,pandl]
                writer.writerow(new_row)
                print("exported trade data")

            if(message['symbol']=='NSE:NIFTYBANK-INDEX' and count>=2):
                    data_type= "SymbolUpdate"
                    symbol_to_unsubscribe= ['NSE:NIFTYBANK-INDEX']
                    wfyers.unsubscribe(symbols= symbol_to_unsubscribe, data_type = data_type)
                    print("unsubscribed") 
#             break

    
    if(status==0 and time.localtime(time.time()).tm_hour>=11 and time.localtime(time.time()).tm_min>=59 and message['symbol']=='NSE:NIFTYBANK-INDEX'):
        data_type= "SymbolUpdate"
        symbol_to_unsubscribe= ['NSE:NIFTYBANK-INDEX']
        wfyers.unsubscribe(symbols= symbol_to_unsubscribe, data_type = data_type)
#         print("unsubscribed")


def onerror(message):
    print("Error:", message)


def onclose(message):
    print("Connection closed:", message)


def onopen():
    data_type = "SymbolUpdate"

    symbols = ['NSE:NIFTYBANK-INDEX']
    wfyers.subscribe(symbols=symbols, data_type=data_type)
    
    wfyers.keep_running()


waccess_token = client_id+":"+access_token 

wfyers = data_ws.FyersDataSocket(
    access_token=waccess_token,       # Access token in the format "appid:accesstoken"
    log_path="",                     # Path to save logs. Leave empty to auto-create logs in the current directory.
    litemode=True,                  # Lite mode disabled. Set to True if you want a lite response.
    write_to_file=False,              # Save response in a log file instead of printing it.
    reconnect=True,                  # Enable auto-reconnection to WebSocket on disconnection.
    on_connect=onopen,               # Callback function to subscribe to data upon connection.
    on_close=onclose,                # Callback function to handle WebSocket connection close events.
    on_error=onerror,                # Callback function to handle WebSocket errors.
    on_message=onmessage            # Callback function to handle incoming messages from the WebSocket.
)

wfyers.connect()
# Out:
# {'type': 'cn', 'code': 200, 'message': 'Authentication done', 's': 'ok'} 	time:  10 7 6
# {'type': 'lit', 'code': 200, 'message': 'Lite Mode On', 's': 'ok'} 	time:  10 7 7
# {'type': 'sub', 'code': 200, 'message': 'Subscribed', 's': 'ok'} 	time:  10 7 8
# {'ltp': 48017.5, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 7 9
# {'ltp': 48017.8, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 7 10
# {'ltp': 48018.0, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 7 11
# {'ltp': 48016.45, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 7 12
# {'ltp': 48018.0, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 7 13
# {'ltp': 48022.8, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 7 14
# {'ltp': 48024.45, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 7 15
# {'ltp': 48024.15, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 7 16
# {'ltp': 48029.15, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 7 17
# {'ltp': 48022.4, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 7 18
# {'ltp': 48025.45, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 7 19
# {'ltp': 48023.95, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 7 20
# {'ltp': 48029.8, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 7 21
# {'ltp': 48026.2, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 7 22
# {'ltp': 48023.25, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 7 23
# {'ltp': 48019.15, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 7 24
# {'ltp': 48024.7, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 7 25
# {'ltp': 48019.5, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 7 26
# {'ltp': 48014.25, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 7 27
# {'ltp': 48014.3, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 7 28
# {'ltp': 48012.95, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 7 29
# {'ltp': 48016.75, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 7 30
# {'ltp': 48014.95, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 7 31
# {'ltp': 48012.65, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 7 32
# {'ltp': 48013.75, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 7 33
# {'ltp': 48011.25, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 7 34
# {'ltp': 48010.3, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 7 35
# {'ltp': 48005.0, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 7 36
# {'ltp': 48015.9, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 7 37
# {'ltp': 48012.35, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 7 38
# {'ltp': 48015.7, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 7 39
# {'ltp': 48013.95, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 7 40
# {'ltp': 48015.95, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 7 41
# {'ltp': 48011.9, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 7 42
# {'ltp': 48011.85, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 7 43
# {'ltp': 48013.55, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 7 44
# {'ltp': 48016.2, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 7 45
# {'ltp': 48017.45, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 7 46
# {'ltp': 48016.8, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 7 47
# {'ltp': 48020.1, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 7 48
# {'ltp': 48017.95, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 7 49
# {'ltp': 48011.15, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 7 50
# {'ltp': 48012.1, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 7 51
# {'ltp': 48012.7, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 7 52
# {'ltp': 48011.6, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 7 53
# {'ltp': 48012.05, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 7 54
# {'ltp': 48013.3, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 7 55
# {'ltp': 48014.8, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 7 56
# {'ltp': 48012.95, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 7 57
# {'ltp': 48013.3, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 7 58
# {'ltp': 48015.2, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 7 59
# {'ltp': 48015.4, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 8 0
# {'ltp': 48015.3, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 8 1
# {'ltp': 48011.4, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 8 2
# {'ltp': 48012.8, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 8 3
# {'ltp': 48014.4, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 8 4
# {'ltp': 48011.7, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 8 5
# {'ltp': 48017.85, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 8 6
# {'ltp': 48015.15, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 8 7
# {'ltp': 48016.1, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 8 8
# {'ltp': 48017.4, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 8 9
# {'ltp': 48017.95, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 8 10
# {'ltp': 48020.5, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 8 11
# {'ltp': 48019.4, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 8 12
# {'ltp': 48015.2, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 8 13
# {'ltp': 48014.2, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 8 14
# {'ltp': 48014.35, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 8 15
# {'ltp': 48013.05, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 8 16
# {'ltp': 48016.95, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 8 17
# {'ltp': 48015.4, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 8 18
# {'ltp': 48017.6, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 8 19
# {'ltp': 48018.1, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 8 20
# {'ltp': 48017.1, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 8 21
# {'ltp': 48016.6, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 8 22
# {'ltp': 48016.9, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 8 23
# {'ltp': 48018.05, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 8 24
# {'ltp': 48016.75, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 8 25
# {'ltp': 48016.0, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 8 26
# {'ltp': 48016.85, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 8 27
# {'ltp': 48018.15, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 8 28
# {'ltp': 48018.5, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 8 29
# {'ltp': 48019.8, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 8 30
# {'ltp': 48016.3, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 8 31
# {'ltp': 48014.7, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 8 32
# {'ltp': 48011.25, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 8 33
# {'ltp': 48012.4, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 8 34
# {'ltp': 48011.85, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 8 35
# {'ltp': 48013.4, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 8 36
# {'ltp': 48014.5, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 8 37
# {'ltp': 48008.3, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 8 39
# {'ltp': 47999.55, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 8 40
# {'ltp': 48001.3, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 8 41
# {'ltp': 48003.9, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 8 42
# {'ltp': 48000.75, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 8 43
# {'ltp': 48000.6, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 8 44
# {'ltp': 47997.55, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 8 45
# {'ltp': 47994.3, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 8 46
# {'ltp': 47996.65, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 8 47
# {'ltp': 47995.95, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 8 48
# {'ltp': 47995.75, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 8 49
# {'ltp': 47990.65, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 8 50
# {'ltp': 47987.85, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 8 51
# {'ltp': 47984.85, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 8 52
# {'ltp': 47991.35, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 8 53
# {'ltp': 47992.65, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 8 54
# {'ltp': 47991.9, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 8 55
# {'ltp': 47993.9, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 8 56
# {'ltp': 47993.2, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 8 57
# {'ltp': 47993.75, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 8 58
# {'ltp': 47992.95, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 8 59
# {'ltp': 47990.75, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 9 0
# {'ltp': 47992.8, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 9 1
# {'ltp': 47992.6, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 9 2
# {'ltp': 47992.1, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 9 3
# {'ltp': 47991.7, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 9 4
# {'ltp': 48000.45, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 9 5
# {'ltp': 48001.05, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 9 6
# {'ltp': 48008.3, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 9 7
# {'ltp': 48010.95, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 9 8
# {'ltp': 48012.25, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 9 9
# {'ltp': 48012.7, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 9 10
# {'ltp': 48010.85, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 9 11
# {'ltp': 48013.2, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 9 12
# {'ltp': 48010.65, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 9 13
# {'ltp': 48016.15, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 9 14
# {'ltp': 48014.15, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 9 15
# {'ltp': 48018.85, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 9 16
# {'ltp': 48017.05, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 9 17
# {'ltp': 48007.45, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 9 18
# {'ltp': 48005.1, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 9 19
# {'ltp': 48004.15, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 9 20
# {'ltp': 48005.25, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 9 21
# {'ltp': 48005.6, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 9 22
# {'ltp': 48003.5, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 9 23
# {'ltp': 48006.15, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 9 24
# {'ltp': 48006.35, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 9 25
# {'ltp': 48001.55, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 9 26
# {'ltp': 48006.4, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 9 27
# {'ltp': 48008.6, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 9 28
# {'ltp': 48006.8, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 9 29
# {'ltp': 48008.85, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 9 30
# {'ltp': 48007.1, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 9 31
# {'ltp': 48006.6, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 9 32
# {'ltp': 48007.3, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 9 33
# {'ltp': 48002.75, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 9 34
# {'ltp': 48003.3, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 9 35
# {'ltp': 48004.0, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 9 36
# {'ltp': 48005.15, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 9 37
# {'ltp': 48006.75, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 9 38
# {'ltp': 48004.8, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 9 39
# {'ltp': 48006.05, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 9 40
# {'ltp': 48002.55, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 9 41
# {'ltp': 48002.75, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 9 42
# {'ltp': 48003.15, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 9 43
# {'ltp': 48004.2, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 9 44
# {'ltp': 48004.0, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 9 45
# {'ltp': 48002.75, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 9 46
# {'ltp': 48000.5, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 9 47
# {'ltp': 48006.2, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 9 48
# {'ltp': 48002.4, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 9 49
# {'ltp': 48003.25, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 9 50
# {'ltp': 48000.85, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 9 51
# {'ltp': 48004.6, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 9 52
# {'ltp': 48002.6, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 9 53
# {'ltp': 48003.65, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 9 54
# {'ltp': 48004.75, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 9 55
# {'ltp': 48005.6, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 9 56
# {'ltp': 48006.3, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 9 57
# {'ltp': 48005.8, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 9 58
# {'ltp': 48003.35, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 9 59
# {'ltp': 48002.35, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 10 0
# {'ltp': 48002.6, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 10 2
# {'ltp': 48003.6, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 10 3
# {'ltp': 48004.65, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 10 4
# {'ltp': 48001.9, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 10 5
# {'ltp': 48003.6, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 10 6
# {'ltp': 48007.55, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 10 7
# {'ltp': 48007.5, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 10 8
# {'ltp': 48009.05, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 10 9
# {'ltp': 48009.3, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 10 10
# {'ltp': 48008.0, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 10 11
# {'ltp': 48002.7, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 10 12
# {'ltp': 48006.05, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 10 13
# {'ltp': 48007.0, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 10 14
# {'ltp': 48008.8, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 10 15
# {'ltp': 48010.95, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 10 16
# {'ltp': 48012.9, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 10 17
# {'ltp': 48003.65, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 10 18
# {'ltp': 48008.4, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 10 19
# {'ltp': 48005.5, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 10 20
# {'ltp': 48004.05, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 10 21
# {'ltp': 48004.9, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 10 22
# {'ltp': 48002.85, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 10 23
# {'ltp': 48002.65, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 10 24
# {'ltp': 48000.0, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 10 25
# {'ltp': 47999.6, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 10 26
# {'ltp': 48000.1, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 10 27
# {'ltp': 47998.0, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 10 28
# {'ltp': 47995.95, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 10 29
# {'ltp': 47999.8, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 10 30
# {'ltp': 47999.4, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 10 31
# {'ltp': 48002.3, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 10 32
# {'ltp': 48002.8, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 10 33
# {'ltp': 47999.8, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 10 34
# {'ltp': 48007.65, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 10 35
# {'ltp': 48006.35, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 10 36
# {'ltp': 48005.3, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 10 37
# {'ltp': 48008.95, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 10 38
# {'ltp': 48008.3, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 10 39
# {'ltp': 48005.95, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 10 40
# {'ltp': 48005.0, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 10 42
# {'ltp': 48003.55, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 10 43
# {'ltp': 48002.3, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 10 44
# {'ltp': 48003.45, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 10 45
# {'ltp': 48002.75, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 10 46
# {'ltp': 48001.85, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 10 47
# {'ltp': 47999.2, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 10 48
# {'ltp': 47998.95, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 10 49
# {'ltp': 47998.85, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 10 50
# {'ltp': 47998.9, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 10 51
# {'ltp': 47997.95, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 10 52
# {'ltp': 47992.55, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 10 53
# {'ltp': 47997.0, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 10 54
# {'ltp': 47997.35, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 10 55
# {'ltp': 47994.5, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 10 56
# {'ltp': 47997.95, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 10 57
# {'ltp': 47996.55, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 10 58
# {'ltp': 48001.05, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 10 59
# {'ltp': 48004.9, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 11 0
# {'ltp': 48002.0, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 11 1
# {'ltp': 48002.7, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 11 2
# {'ltp': 48003.4, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 11 3
# {'ltp': 48003.0, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 11 4
# {'ltp': 48003.9, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 11 5
# {'ltp': 48001.3, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 11 6
# {'ltp': 48004.95, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 11 7
# {'ltp': 48006.55, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 11 8
# {'ltp': 48005.75, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 11 9
# {'ltp': 48005.9, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 11 10
# {'ltp': 48005.95, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 11 11
# {'ltp': 48004.0, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 11 12
# {'ltp': 48009.1, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 11 13
# {'ltp': 48011.0, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 11 14
# {'ltp': 48012.55, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 11 15
# {'ltp': 48013.7, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 11 16
# {'ltp': 48011.95, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 11 17
# {'ltp': 48010.15, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 11 18
# {'ltp': 48008.2, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 11 19
# {'ltp': 48012.9, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 11 20
# {'ltp': 48008.1, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 11 21
# {'ltp': 48010.1, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 11 22
# {'ltp': 48003.85, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 11 23
# {'ltp': 48001.55, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 11 24
# {'ltp': 48004.9, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 11 25
# {'ltp': 48003.95, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 11 26
# {'ltp': 48003.6, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 11 27
# {'ltp': 48005.0, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 11 28
# {'ltp': 48005.65, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 11 29
# {'ltp': 48006.05, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 11 30
# {'ltp': 48005.95, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 11 31
# {'ltp': 48002.95, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 11 32
# {'ltp': 47999.15, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 11 33
# {'ltp': 47998.65, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 11 34
# {'ltp': 47998.2, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 11 35
# {'ltp': 47995.7, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 11 36
# {'ltp': 47995.2, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 11 37
# {'ltp': 47995.95, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 11 38
# {'ltp': 47998.55, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 11 39
# {'ltp': 47997.3, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 11 40
# {'ltp': 47996.8, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 11 41
# {'ltp': 47997.15, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 11 42
# {'ltp': 48000.2, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 11 43
# {'ltp': 47998.75, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 11 44
# {'ltp': 47999.4, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 11 45
# {'ltp': 47999.2, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 11 46
# {'ltp': 47996.4, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 11 47
# {'ltp': 47995.4, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 11 48
# {'ltp': 47998.75, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 11 49
# {'ltp': 47997.35, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 11 50
# {'ltp': 47997.45, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 11 51
# {'ltp': 48000.05, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 11 52
# {'ltp': 47999.7, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 11 53
# {'ltp': 47998.95, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 11 54
# {'ltp': 47998.35, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 11 55
# {'ltp': 47999.9, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 11 56
# {'ltp': 48001.3, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 11 57
# {'ltp': 48000.1, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 11 58
# {'ltp': 48002.15, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 11 59
# {'ltp': 48000.5, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 12 0
# {'ltp': 48001.9, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 12 1
# {'ltp': 48003.5, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 12 2
# {'ltp': 48002.65, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 12 3
# {'ltp': 48003.65, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 12 4
# {'ltp': 48003.1, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 12 5
# {'ltp': 48000.1, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 12 6
# {'ltp': 48002.45, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 12 7
# {'ltp': 48005.05, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 12 8
# {'ltp': 48007.4, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 12 9
# {'ltp': 48006.45, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 12 10
# {'ltp': 47999.9, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 12 11
# {'ltp': 48001.75, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 12 12
# {'ltp': 47999.75, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 12 13
# {'ltp': 48000.85, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 12 14
# {'ltp': 47995.2, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 12 15
# {'ltp': 48003.95, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 12 16
# {'ltp': 48002.85, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 12 18
# {'ltp': 47999.3, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 12 19
# {'ltp': 47997.95, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 12 20
# {'ltp': 47998.95, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 12 21
# {'ltp': 47998.5, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 12 22
# {'ltp': 48005.4, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 12 23
# {'ltp': 47991.85, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 12 24
# {'ltp': 47996.05, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 12 25
# {'ltp': 47992.45, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 12 26
# {'ltp': 47997.6, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 12 27
# {'ltp': 47993.1, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 12 28
# {'ltp': 47993.15, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 12 29
# {'ltp': 47994.95, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 12 30
# {'ltp': 47992.15, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 12 31
# {'ltp': 47991.0, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 12 32
# {'ltp': 47994.15, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 12 33
# {'ltp': 47994.1, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 12 34
# {'ltp': 47994.7, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 12 35
# {'ltp': 47991.25, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 12 36
# {'ltp': 47994.95, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 12 37
# {'ltp': 47993.75, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 12 38
# {'ltp': 47989.4, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 12 39
# {'ltp': 47986.2, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 12 40
# {'ltp': 47984.2, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 12 41
# {'ltp': 47968.25, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 12 42
# {'ltp': 47966.4, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 12 43
# {'ltp': 47964.8, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 12 44
# {'ltp': 47965.7, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 12 45
# {'ltp': 47960.35, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 12 46
# {'ltp': 47949.9, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 12 47
# {'ltp': 47944.2, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 12 48
# {'ltp': 47944.15, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 12 49
# {'ltp': 47952.5, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 12 50
# {'ltp': 47950.25, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 12 51
# {'ltp': 47938.05, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 12 52
# {'ltp': 47947.8, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 12 53
# {'ltp': 47951.7, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 12 54
# {'ltp': 47956.35, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 12 55
# {'ltp': 47954.6, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 12 56
# {'ltp': 47949.6, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 12 57
# {'ltp': 47944.1, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 12 58
# {'ltp': 47953.3, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 12 59
# {'ltp': 47953.55, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 13 0
# {'ltp': 47948.95, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 13 1
# {'ltp': 47946.9, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 13 2
# {'ltp': 47944.0, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 13 3
# {'ltp': 47948.65, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 13 4
# {'ltp': 47954.4, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 13 5
# {'ltp': 47953.3, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 13 6
# {'ltp': 47950.3, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 13 7
# {'ltp': 47946.0, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 13 8
# {'ltp': 47954.55, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 13 9
# {'ltp': 47949.2, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 13 10
# {'ltp': 47949.7, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 13 11
# {'ltp': 47946.9, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 13 12
# {'ltp': 47939.2, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 13 13
# {'ltp': 47944.7, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 13 14
# {'ltp': 47942.4, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 13 15
# {'ltp': 47944.1, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 13 16
# {'ltp': 47940.35, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 13 17
# {'ltp': 47944.6, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 13 18
# {'ltp': 47940.45, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 13 19
# {'ltp': 47933.1, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 13 20
# {'ltp': 47934.55, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 13 21
# {'ltp': 47941.75, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 13 22
# {'ltp': 47922.35, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 13 23
# {'ltp': 47939.15, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 13 24
# {'ltp': 47935.1, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 13 25
# {'ltp': 47933.2, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 13 26
# {'ltp': 47932.9, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 13 27
# {'ltp': 47937.7, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 13 28
# {'ltp': 47933.95, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 13 29
# {'ltp': 47926.15, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 13 30
# {'ltp': 47935.55, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 13 31
# {'ltp': 47937.95, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 13 32
# {'ltp': 47937.75, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 13 33
# {'ltp': 47927.5, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 13 34
# {'ltp': 47935.8, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 13 35
# {'ltp': 47937.45, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 13 36
# {'ltp': 47939.95, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 13 37
# {'ltp': 47937.5, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 13 38
# {'ltp': 47940.8, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 13 39
# {'ltp': 47942.2, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 13 40
# {'ltp': 47941.65, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 13 41
# {'ltp': 47945.3, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 13 42
# {'ltp': 47943.3, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 13 44
# {'ltp': 47946.05, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 13 45
# {'ltp': 47942.75, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 13 46
# {'ltp': 47946.5, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 13 47
# {'ltp': 47945.0, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 13 48
# {'ltp': 47938.6, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 13 49
# {'ltp': 47937.1, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 13 50
# {'ltp': 47939.95, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 13 51
# {'ltp': 47939.05, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 13 52
# {'ltp': 47939.7, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 13 53
# {'ltp': 47939.0, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 13 54
# {'ltp': 47937.55, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 13 55
# {'ltp': 47936.4, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 13 56
# {'ltp': 47935.4, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 13 57
# {'ltp': 47936.25, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 13 58
# {'ltp': 47937.7, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 13 59
# {'ltp': 47940.65, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 14 0
# {'ltp': 47941.25, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 14 1
# {'ltp': 47938.4, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 14 2
# {'ltp': 47936.85, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 14 3
# {'ltp': 47941.6, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 14 4
# {'ltp': 47948.1, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 14 5
# {'ltp': 47949.85, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 14 6
# {'ltp': 47952.3, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 14 7
# {'ltp': 47950.3, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 14 8
# {'ltp': 47954.65, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 14 9
# {'ltp': 47955.55, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 14 10
# {'ltp': 47957.15, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 14 11
# {'ltp': 47956.5, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 14 12
# {'ltp': 47956.55, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 14 13
# {'ltp': 47952.1, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 14 14
# {'ltp': 47956.55, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 14 15
# {'ltp': 47956.25, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 14 16
# {'ltp': 47955.15, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 14 17
# {'ltp': 47955.35, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 14 18
# {'ltp': 47958.6, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 14 19
# {'ltp': 47958.05, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 14 20
# {'ltp': 47957.65, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 14 21
# {'ltp': 47956.25, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 14 22
# {'ltp': 47954.6, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 14 23
# {'ltp': 47956.45, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 14 24
# {'ltp': 47958.2, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 14 25
# {'ltp': 47960.75, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 14 26
# {'ltp': 47959.15, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 14 27
# {'ltp': 47957.2, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 14 28
# {'ltp': 47957.9, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 14 29
# {'ltp': 47958.8, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 14 30
# {'ltp': 47958.2, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 14 31
# {'ltp': 47963.85, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 14 32
# {'ltp': 47964.6, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 14 33
# {'ltp': 47967.95, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 14 34
# {'ltp': 47967.3, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 14 35
# {'ltp': 47966.05, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 14 36
# {'ltp': 47965.65, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 14 37
# {'ltp': 47969.5, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 14 38
# {'ltp': 47973.75, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 14 39
# {'ltp': 47977.05, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 14 40
# {'ltp': 47978.05, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 14 41
# {'ltp': 47977.7, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 14 42
# {'ltp': 47977.3, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 14 43
# {'ltp': 47975.4, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 14 44
# {'ltp': 47975.95, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 14 45
# {'ltp': 47979.05, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 14 46
# {'ltp': 47972.0, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 14 47
# {'ltp': 47969.1, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 14 48
# {'ltp': 47972.2, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 14 49
# {'ltp': 47977.0, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 14 50
# {'ltp': 47972.4, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 14 51
# {'ltp': 47969.5, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 15 26
# {'ltp': 47968.65, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 15 27
# {'ltp': 47967.95, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 15 28
# {'ltp': 47968.5, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 15 29
# {'ltp': 47969.9, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 15 30
# {'ltp': 47967.8, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 15 31
# {'ltp': 47966.4, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 15 32
# {'ltp': 47967.9, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 15 33
# {'ltp': 47968.25, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 15 34
# {'ltp': 47968.2, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 15 35
# {'ltp': 47968.65, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 15 36
# {'ltp': 47967.6, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 15 37
# {'ltp': 47972.1, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 15 38
# {'ltp': 47975.45, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 15 39
# {'ltp': 47969.15, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 15 40
# {'ltp': 47972.9, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 15 41
# {'ltp': 47973.45, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 15 42
# {'ltp': 47976.45, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 15 43
# {'ltp': 47973.05, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 15 44
# {'ltp': 47970.8, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 15 45
# {'ltp': 47973.55, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 15 46
# Exception in thread Thread-7 (__ping):
# Traceback (most recent call last):
#   File "C:\Users\Admin\anaconda3\lib\threading.py", line 1016, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Admin\anaconda3\lib\threading.py", line 953, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\Admin\anaconda3\lib\site-packages\fyers_apiv3\FyersWebsocket\data_ws.py", line 1625, in __ping
#     self.__ws_object.send("ping")
#   File "C:\Users\Admin\anaconda3\lib\site-packages\websocket\_app.py", line 249, in send
#     if not self.sock or self.sock.send(data, opcode) == 0:
#   File "C:\Users\Admin\anaconda3\lib\site-packages\websocket\_core.py", line 283, in send
#     return self.send_frame(frame)
#   File "C:\Users\Admin\anaconda3\lib\site-packages\websocket\_core.py", line 311, in send_frame
#     l = self._send(data)
#   File "C:\Users\Admin\anaconda3\lib\site-packages\websocket\_core.py", line 525, in _send
#     return send(self.sock, data)
#   File "C:\Users\Admin\anaconda3\lib\site-packages\websocket\_socket.py", line 170, in send
#     return _send()
#   File "C:\Users\Admin\anaconda3\lib\site-packages\websocket\_socket.py", line 147, in _send
#     return sock.send(data)
#   File "C:\Users\Admin\anaconda3\lib\ssl.py", line 1206, in send
#     return self._sslobj.write(data)
# ssl.SSLEOFError: EOF occurred in violation of protocol (_ssl.c:2396)
# {'ltp': 47971.8, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 15 47
# {'ltp': 47972.75, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 15 48
# {'ltp': 47972.1, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 15 49
# {'ltp': 47973.4, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 15 50
# {'ltp': 47972.2, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 15 51
# {'ltp': 47972.65, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 15 52
# {'ltp': 47971.45, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 15 53
# {'ltp': 47971.3, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 15 54
# {'ltp': 47973.25, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 15 55
# {'ltp': 47971.8, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 15 56
# {'ltp': 47972.55, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 15 57
# {'ltp': 47974.95, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 15 58
# {'ltp': 47971.0, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 15 59
# Error: Connection to remote host was lost.
# Attempting reconnect 1 of 5...
# {'type': 'cn', 'code': 200, 'message': 'Authentication done', 's': 'ok'} 	time:  10 16 5
# {'type': 'lit', 'code': 200, 'message': 'Lite Mode On', 's': 'ok'} 	time:  10 16 6
# {'type': 'sub', 'code': 200, 'message': 'Subscribed', 's': 'ok'} 	time:  10 16 7
# {'ltp': 47979.65, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 16 8
# {'ltp': 47979.55, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 16 9
# {'ltp': 47980.05, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 16 10
# {'ltp': 47982.2, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 16 11
# {'ltp': 47979.35, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 16 12
# {'ltp': 47984.55, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 16 13
# {'ltp': 47981.75, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 16 14
# {'ltp': 47976.85, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 16 15
# {'ltp': 47978.45, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 16 16
# {'ltp': 47980.7, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 16 17
# {'ltp': 47980.85, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 16 18
# {'ltp': 47981.0, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 16 19
# {'ltp': 47976.05, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 16 20
# {'ltp': 47976.3, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 16 21
# {'ltp': 47976.25, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 16 22
# {'ltp': 47974.1, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 16 23
# {'ltp': 47975.85, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 16 24
# {'ltp': 47978.7, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 16 25
# {'ltp': 47981.05, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 16 26
# {'ltp': 47979.9, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 16 27
# {'ltp': 47978.45, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 16 28
# {'ltp': 47978.75, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 16 29
# {'ltp': 47981.25, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 16 30
# {'ltp': 47977.9, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 16 31
# {'ltp': 47979.95, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 16 32
# {'ltp': 47977.15, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 16 33
# {'ltp': 47977.7, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 16 34
# {'ltp': 47977.55, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 16 35
# {'ltp': 47978.9, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 16 36
# {'ltp': 47979.5, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 16 37
# {'ltp': 47981.15, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 16 38
# {'ltp': 47979.95, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 16 39
# {'ltp': 47982.8, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 16 40
# {'ltp': 47981.15, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 16 41
# {'ltp': 47981.35, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 16 42
# {'ltp': 47982.85, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 16 43
# {'ltp': 47978.9, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 16 44
# {'ltp': 47979.25, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 16 45
# {'ltp': 47979.65, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 16 46
# {'ltp': 47979.2, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 16 47
# {'ltp': 47979.7, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 16 48
# {'ltp': 47980.05, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 16 49
# {'ltp': 47972.2, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 16 50
# {'ltp': 47973.1, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 16 51
# {'ltp': 47970.45, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 16 52
# {'ltp': 47967.65, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 16 54
# {'ltp': 47967.2, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 16 55
# {'ltp': 47965.65, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 16 56
# {'ltp': 47961.4, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 16 57
# {'ltp': 47959.5, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 16 58
# {'ltp': 47959.75, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 16 59
# {'ltp': 47957.4, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 17 0
# {'ltp': 47957.85, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 17 1
# {'ltp': 47959.05, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 17 2
# {'ltp': 47959.2, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 17 3
# {'ltp': 47959.05, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 17 4
# {'ltp': 47961.2, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 17 5
# {'ltp': 47955.35, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 17 6
# {'ltp': 47959.15, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 17 7
# {'ltp': 47960.3, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 17 8
# {'ltp': 47958.4, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 17 9
# {'ltp': 47959.5, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 17 10
# {'ltp': 47956.6, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 17 11
# {'ltp': 47956.15, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 17 12
# {'ltp': 47954.85, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 17 13
# {'ltp': 47954.15, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 17 14
# {'ltp': 47955.65, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 17 15
# {'ltp': 47953.95, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 17 16
# {'ltp': 47958.0, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 17 17
# {'ltp': 47956.45, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 17 18
# {'ltp': 47956.7, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 17 19
# {'ltp': 47955.5, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 17 20
# {'ltp': 47955.55, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 17 21
# {'ltp': 47948.65, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 17 22
# {'ltp': 47949.2, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 17 23
# {'ltp': 47946.2, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  10 17 24
# ...
# {'ltp': 47821.75, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  14 14 3
# {'ltp': 47821.0, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  14 14 4
# {'ltp': 47822.85, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  14 14 5
# {'ltp': 47822.2, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  14 14 6
# {'ltp': 47822.3, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  14 14 7
# {'ltp': 47823.25, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  14 14 8
# {'ltp': 47823.15, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  14 14 9
# {'ltp': 47822.2, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  14 14 10
# {'ltp': 47822.55, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  14 14 11
# {'ltp': 47822.1, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  14 14 12
# {'ltp': 47824.65, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  14 14 13
# {'ltp': 47824.65, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  14 14 14
# {'ltp': 47820.6, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  14 14 15
# {'ltp': 47823.75, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  14 14 16
# {'ltp': 47822.7, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  14 14 17
# {'ltp': 47824.3, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  14 14 18
# {'ltp': 47826.0, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  14 14 19
# {'ltp': 47828.05, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  14 14 20
# {'ltp': 47829.45, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  14 14 21
# {'ltp': 47831.25, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  14 14 22
# {'ltp': 47831.45, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  14 14 23
# {'ltp': 47830.3, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  14 14 24
# {'ltp': 47829.4, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  14 14 25
# {'ltp': 47830.4, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  14 14 26
# {'ltp': 47830.9, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  14 14 27
# {'ltp': 47830.4, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  14 14 28
# {'ltp': 47829.5, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  14 14 29
# {'ltp': 47824.85, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  14 14 30
# {'ltp': 47829.7, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  14 14 31
# {'ltp': 47828.65, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  14 14 32
# {'ltp': 47827.25, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  14 14 33
# {'ltp': 47826.45, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  14 14 34
# {'ltp': 47826.85, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  14 14 35
# {'ltp': 47825.7, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  14 14 36
# {'ltp': 47824.95, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  14 14 37
# {'ltp': 47827.4, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  14 14 38
# {'ltp': 47824.3, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  14 14 39
# {'ltp': 47824.7, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  14 14 40
# {'ltp': 47826.85, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  14 14 41
# {'ltp': 47826.45, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  14 14 42
# {'ltp': 47826.25, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  14 14 43
# {'ltp': 47827.1, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  14 14 44
# {'ltp': 47826.85, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  14 14 45
# {'ltp': 47821.8, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  14 14 46
# {'ltp': 47825.2, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  14 14 47
# {'ltp': 47825.5, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  14 14 48
# {'ltp': 47823.6, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  14 14 49
# {'ltp': 47823.2, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  14 14 50
# {'ltp': 47825.35, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  14 14 51
# {'ltp': 47823.75, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  14 14 52
# {'ltp': 47824.35, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  14 14 53
# {'ltp': 47824.9, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  14 14 54
# {'ltp': 47824.25, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  14 14 55
# {'ltp': 47827.15, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  14 14 56
# {'ltp': 47825.1, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  14 14 57
# {'ltp': 47827.0, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  14 14 58
# {'ltp': 47826.35, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  14 14 59
# {'ltp': 47825.8, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  14 15 1
# {'ltp': 47827.9, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  14 15 2
# {'ltp': 47828.3, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  14 15 3
# {'ltp': 47828.25, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  14 15 4
# {'ltp': 47828.0, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  14 15 5
# {'ltp': 47829.55, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  14 15 6
# {'ltp': 47827.55, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  14 15 7
# {'ltp': 47827.25, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  14 15 8
# {'ltp': 47830.55, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  14 15 10
# {'ltp': 47830.3, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  14 15 11
# {'ltp': 47827.6, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  14 15 12
# {'ltp': 47834.0, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  14 15 13
# {'ltp': 47831.15, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  14 15 14
# {'ltp': 47827.5, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  14 15 15
# {'ltp': 47833.45, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  14 15 16
# {'ltp': 47828.0, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  14 15 17
# {'ltp': 47827.75, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  14 15 19
# {'ltp': 47828.55, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  14 15 20
# {'ltp': 47827.1, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  14 15 21
# {'ltp': 47827.2, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  14 15 22
# {'ltp': 47828.25, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  14 15 23
# {'ltp': 47829.0, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  14 15 24
# {'ltp': 47828.25, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  14 15 26
# {'ltp': 47829.7, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  14 15 27
# {'ltp': 47827.7, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  14 15 28
# {'ltp': 47829.3, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  14 15 30
# {'ltp': 47830.75, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  14 15 31
# {'ltp': 47826.85, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  14 15 32
# {'ltp': 47826.9, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  14 15 33
# {'ltp': 47825.7, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  14 15 34
# {'ltp': 47825.45, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  14 15 36
# {'ltp': 47826.3, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  14 15 37
# {'ltp': 47826.0, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  14 15 38
# {'ltp': 47825.65, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  14 15 39
# {'ltp': 47823.65, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  14 15 40
# {'ltp': 47827.6, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  14 15 41
# {'ltp': 47826.15, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  14 15 42
# {'ltp': 47825.3, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  14 15 43
# {'ltp': 47827.75, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  14 15 45
# {'ltp': 47825.55, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  14 15 46
# {'ltp': 47825.3, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  14 15 47
# {'ltp': 47825.9, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  14 15 48
# {'ltp': 47826.5, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  14 15 49
# {'ltp': 47821.95, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  14 15 50
# {'ltp': 47829.25, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  14 15 51
# {'ltp': 47832.0, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  14 15 53
# {'ltp': 47824.3, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  14 15 54
# {'ltp': 47824.0, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  14 15 55
# {'ltp': 47827.45, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  14 15 56
# {'ltp': 47827.15, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  14 15 57
# {'ltp': 47826.3, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  14 15 58
# {'ltp': 47829.4, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  14 15 59
# {'ltp': 47830.45, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  14 16 1
# {'ltp': 47830.15, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  14 16 2
# {'ltp': 47831.0, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  14 16 3
# {'ltp': 47828.25, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  14 16 4
# {'ltp': 47828.0, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  14 16 5
# {'ltp': 47827.65, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  14 16 6
# {'ltp': 47825.65, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  14 16 8
# {'ltp': 47826.8, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  14 16 9
# {'ltp': 47826.3, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  14 16 10
# {'ltp': 47824.9, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  14 16 11
# {'ltp': 47824.1, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  14 16 12
# {'ltp': 47826.7, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  14 16 13
# {'ltp': 47825.85, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  14 16 15
# {'ltp': 47825.65, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  14 16 16
# {'ltp': 47826.5, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  14 16 17
# {'ltp': 47826.85, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  14 16 18
# {'ltp': 47830.35, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  14 16 19
# {'ltp': 47829.35, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  14 16 20
# {'ltp': 47829.95, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  14 16 22
# {'ltp': 47831.05, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  14 16 23
# {'ltp': 47831.4, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  14 16 24
# {'ltp': 47828.5, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  14 16 25
# {'ltp': 47832.05, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  14 16 27
# {'ltp': 47832.05, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  14 16 28
# {'ltp': 47823.35, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  14 16 29
# {'ltp': 47828.85, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  14 16 31
# {'ltp': 47830.5, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  14 16 32
# {'ltp': 47828.15, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  14 16 33
# {'ltp': 47830.1, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  14 16 34
# {'ltp': 47831.6, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  14 16 35
# {'ltp': 47829.15, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  14 16 36
# {'ltp': 47829.75, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  14 16 37
# {'ltp': 47829.05, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  14 16 39
# {'ltp': 47830.4, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  14 16 40
# {'ltp': 47829.45, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  14 16 41
# {'ltp': 47828.0, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  14 16 42
# {'ltp': 47831.0, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  14 16 43
# {'ltp': 47827.35, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  14 16 44
# {'ltp': 47829.3, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  14 16 46
# {'ltp': 47830.9, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  14 16 47
# {'ltp': 47830.45, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  14 16 48
# {'ltp': 47828.4, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  14 16 49
# {'ltp': 47828.15, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  14 16 50
# {'ltp': 47828.5, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  14 16 51
# {'ltp': 47828.75, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  14 16 52
# {'ltp': 47828.1, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  14 16 54
# {'ltp': 47826.45, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  14 16 55
# {'ltp': 47826.25, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  14 16 56
# {'ltp': 47827.2, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  14 16 57
# {'ltp': 47829.25, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  14 16 58
# {'ltp': 47830.25, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  14 16 59
# {'ltp': 47831.35, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  14 17 0
# {'ltp': 47829.7, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  14 17 2
# {'ltp': 47829.15, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  14 17 3
# {'ltp': 47824.25, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  14 17 5
# {'ltp': 47828.4, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  14 17 6
# {'ltp': 47828.2, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  14 17 7
# {'ltp': 47828.1, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  14 17 8
# {'ltp': 47828.3, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  14 17 10
# {'ltp': 47831.35, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  14 17 11
# {'ltp': 47831.15, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  14 17 12
# {'ltp': 47828.15, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  14 17 13
# {'ltp': 47829.6, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  14 17 14
# {'ltp': 47833.55, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  14 17 15
# {'ltp': 47829.5, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  14 17 16
# {'ltp': 47829.6, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  14 17 18
# {'ltp': 47832.65, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  14 17 19
# {'ltp': 47832.05, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  14 17 20
# {'ltp': 47831.55, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  14 17 21
# {'ltp': 47831.45, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  14 17 22
# {'ltp': 47829.55, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  14 17 23
# {'ltp': 47828.05, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  14 17 24
# {'ltp': 47828.8, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  14 17 26
# {'ltp': 47829.8, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  14 17 27
# {'ltp': 47830.0, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  14 17 28
# {'ltp': 47830.4, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  14 17 29
# {'ltp': 47829.25, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  14 17 30
# {'ltp': 47827.95, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  14 17 31
# {'ltp': 47829.1, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  14 17 33
# {'ltp': 47830.95, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  14 17 34
# {'ltp': 47829.6, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  14 17 35
# {'ltp': 47834.5, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  14 17 37
# {'ltp': 47839.85, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  14 17 39
# {'ltp': 47836.4, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  14 17 40
# {'ltp': 47836.2, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  14 17 41
# {'ltp': 47837.4, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  14 17 42
# {'ltp': 47839.7, 'symbol': 'NSE:NIFTYBANK-INDEX', 'type': 'if'} 	time:  14 17 43
