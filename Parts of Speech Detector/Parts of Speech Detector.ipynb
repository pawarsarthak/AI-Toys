# %%
import nltk
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')
nltk.download('universal_tagset')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\dell\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\dell\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package universal_tagset to
# [nltk_data]     C:\Users\dell\AppData\Roaming\nltk_data...
# [nltk_data]   Package universal_tagset is already up-to-date!
# True

# %%
from nltk import word_tokenize,punkt

# %%
article =("""Cybercrime police clamp down on violations against children
MISUSING SOCIAL MEDIA Experts say many do not know what content would land them in trouble
Farhan Shaikh farhan.shaikh@htlive.com
NAVIMUMBAI: A week after Union minister Ravi Shankar Prasad's speech in the Lok Sabha on the growing menace of child pornog raphy in the country, the Navi Mumbai cybercrime cell has identified 21 people across the city who published child porno- graphic content on social media.
In the past one week, the police have arrested four people for such crimes and are working to trace more, officials said.
"We aretracing the 21 accused and strict action will continue against the people. In many cases, the people are emboldened as they feel the virtual world pro- vides them a cover of anonymity, but our investigations always uncover it," said Jayraj Chap- aria, senior police inspector from cybercrime cell, Navi Mumbai
Among the four arrested, the Kopar Khairane police have arrested a house painter and a BMS graduate working with a private firm while the Uran police and NRI police station have arrested one person each.
The cyber cell sprang into action after the National Cyber Crime Reporting Portal (NCCRP) supplied them with the suspected URLs commonly known as web addresses.
In one case, a painter Amit Hussain, 25, bought a phone using documents of his room- mate. Hussain arrived from Madhya Pradesh to find a job in the city and was staying in a chawl, said police. He uploaded a pornographic content involving aminor child on his social media account which NCCRP later traced.
ILLUSTRATION
SHRIKRISHNA
The BMS graduate Suraj Sachdev, 29, allegedly told police that he found the video innocent which involved a "disrobed child with his parents".
Police, however, said they have not verified his claims dur- ing investigations at the police station although the NCCRP has provided them with a video CD. "The duo was arrested and produced in court which released them on bail. With the strict action, we hope those mis- using social media will be warned from indulging in this crime," said Nishikant Vish- wakar, inspector at Kopar Khairane police station.
Cyber cell officers said they havenot come across a sustained racket where child sexual abuse material (CSAM) is being circu- lated since it is already actively blocked at the central level. Offi- cials termed these arrests spo- radic.
Navi Mumbai police commis- sioner Sanjay Kumar recently held a session with college stu- dents to educate them on the use of social media.
ABOUT THE ACT
Protection of Children from Sexual Offences (POCSO) Act, 2012:
Section 14 and Section 15
RECENT ARRESTS
In the past one week, the police have arrested four people for uploading child pornographic content on social media.
The police have seized the mobile phones of the arrested accused and will continue with
"Youngsters spend quite a lot of time on social media and often some people would send a link or a post containing obscenity with- out thinking how it will be per- ceived by the receiver," added Chaparia.
In WhatsApp groups, it is likely you are a part of a group where more than half of the group members arenot known to you.
In such cases, it is likely that someone would post a mischie- vous link on the group, said police.
Cybercrime investigator Ritesh Bhatia blamed the cases on lack of awareness.
"People need to be made aware that not just storing it but also viewing it is a crime.Compa- nies need todo more to block it at the root level," said Bhatia.
While the police keep a watch- ful eye on social media during elections throughout the year, officials said admins of the groups are asked to ensure civil- ity is maintained in these groups and uploading of CSAM is reported to the police at the earli-
inscribe punishment for using a child for pornographic purpose and for storage of pornographic material involving a child.
investigations. Police sources said based on their findings in the probe, they will decide whether to press charges of stringent POCSO Act which subscribe a stricter punishment. It also will reduce the accused's chances of securing a bail.
est.
Cyber psychologist Nirali Bhatia said India has two types of CSAM users-actual paedo- philes and accidental CSAM users, who watch it for curiosity, both of which are a criminal offence.
"Accessibility to internet has changed the way crimes are com- mitted. The nature of the inter- net is such that even after one block CSAM at one end, it will surface through other social media," she added.
Bhatia said that in some cases the police fall short in taking immediate action against the perpetrators.
In one such case, in a villagein rural Maharashtra, villagers spotted a teenage couple sitting cosily. The men forced the cou- ple to perform sexual acts and recorded it and posted it viral on the social media. The accused were arrested.
CYBER CELL OFFICERS SAID THEY HAVE NOT COME ACROSS A SUSTAINED RACKET WHERE CHILD SEXUAL ABUSE MATERIAL IS BEING CIRCULATED
ity on popular social media plat- forms to help the police arrest the criminals. The companies would give excuses like privacy but they should understand that nothing comes above child pro- tection," Bhatia added.
While there is a market for CSAM in the western countries and in eastern states, Ritesh said India has not reached that stage but most of these creators of CSAM do so for personal sense of achievement and circulate it with the help of easily available data.
"From the perspective of a child, who is victimised, it is more scaling towards exploita- tion than a systematic monetary profit from the CSAM," he added.
GOVT STATEMENT
In their statement in July last year, the Ministry of Women and Child Development said, "The government blocks the websites containing extreme Child Sexual Abuse Material (CSAM) based on interpol's worst-of-list shared periodically by Central Bureau of Investigation (CBI) which is the National Nodal Agency for In cases involving people Interpol. The list is shared with actively searching for CSAM Department of Telecommunica- content, they fall directly on the tions (DoT), who then directs wrong side. major Internet Service Provid- "There is a huge responsibil- ers to block such websites.""")

# %%
labels = word_tokenize(article)

# %%
POS = nltk.pos_tag(labels, tagset = "universal")

# %%
POS
# Out:
# [('Cybercrime', 'NOUN'),
#  ('police', 'NOUN'),
#  ('clamp', 'VERB'),
#  ('down', 'ADV'),
#  ('on', 'ADP'),
#  ('violations', 'NOUN'),
#  ('against', 'ADP'),
#  ('children', 'NOUN'),
#  ('MISUSING', 'NOUN'),
#  ('SOCIAL', 'NOUN'),
#  ('MEDIA', 'NOUN'),
#  ('Experts', 'NOUN'),
#  ('say', 'VERB'),
#  ('many', 'ADJ'),
#  ('do', 'VERB'),
#  ('not', 'ADV'),
#  ('know', 'VERB'),
#  ('what', 'PRON'),
#  ('content', 'NOUN'),
#  ('would', 'VERB'),
#  ('land', 'VERB'),
#  ('them', 'PRON'),
#  ('in', 'ADP'),
#  ('trouble', 'NOUN'),
#  ('Farhan', 'NOUN'),
#  ('Shaikh', 'NOUN'),
#  ('farhan.shaikh', 'NOUN'),
#  ('@', 'NOUN'),
#  ('htlive.com', 'NOUN'),
#  ('NAVIMUMBAI', 'NOUN'),
#  (':', '.'),
#  ('A', 'DET'),
#  ('week', 'NOUN'),
#  ('after', 'ADP'),
#  ('Union', 'NOUN'),
#  ('minister', 'NOUN'),
#  ('Ravi', 'NOUN'),
#  ('Shankar', 'NOUN'),
#  ('Prasad', 'NOUN'),
#  ("'s", 'PRT'),
#  ('speech', 'NOUN'),
#  ('in', 'ADP'),
#  ('the', 'DET'),
#  ('Lok', 'NOUN'),
#  ('Sabha', 'NOUN'),
# ...

# %% [raw]
# Legend For Parts of Speech
#
# VERB — verbs (all tenses and modes)
# NOUN — nouns (common and proper)
# PRON — pronouns
# ADJ  — adjectives
# ADV  — adverbs
# ADP  — adpositions (prepositions and postpositions)
# CONJ — conjunctions
# DET  — determiners
# NUM  — cardinal numbers
# PRT  — particles or other function words
# X    — other: foreign words, typos, abbreviations
# .    — punctuation

# %%
POS = [list(i) for i in POS]

# %%
POS
# Out:
# [['Cybercrime', 'NOUN'],
#  ['police', 'NOUN'],
#  ['clamp', 'VERB'],
#  ['down', 'ADV'],
#  ['on', 'ADP'],
#  ['violations', 'NOUN'],
#  ['against', 'ADP'],
#  ['children', 'NOUN'],
#  ['MISUSING', 'NOUN'],
#  ['SOCIAL', 'NOUN'],
#  ['MEDIA', 'NOUN'],
#  ['Experts', 'NOUN'],
#  ['say', 'VERB'],
#  ['many', 'ADJ'],
#  ['do', 'VERB'],
#  ['not', 'ADV'],
#  ['know', 'VERB'],
#  ['what', 'PRON'],
#  ['content', 'NOUN'],
#  ['would', 'VERB'],
#  ['land', 'VERB'],
#  ['them', 'PRON'],
#  ['in', 'ADP'],
#  ['trouble', 'NOUN'],
#  ['Farhan', 'NOUN'],
#  ['Shaikh', 'NOUN'],
#  ['farhan.shaikh', 'NOUN'],
#  ['@', 'NOUN'],
#  ['htlive.com', 'NOUN'],
#  ['NAVIMUMBAI', 'NOUN'],
#  [':', '.'],
#  ['A', 'DET'],
#  ['week', 'NOUN'],
#  ['after', 'ADP'],
#  ['Union', 'NOUN'],
#  ['minister', 'NOUN'],
#  ['Ravi', 'NOUN'],
#  ['Shankar', 'NOUN'],
#  ['Prasad', 'NOUN'],
#  ["'s", 'PRT'],
#  ['speech', 'NOUN'],
#  ['in', 'ADP'],
#  ['the', 'DET'],
#  ['Lok', 'NOUN'],
#  ['Sabha', 'NOUN'],
# ...

# %%
import pandas as pd

# %%
df = pd.DataFrame(POS,columns=['WORD','POS'])

# %%
df
# Out:
#             WORD   POS
# 0     Cybercrime  NOUN
# 1         police  NOUN
# 2          clamp  VERB
# 3           down   ADV
# 4             on   ADP
# ...          ...   ...
# 1152          to   PRT
# 1153       block  VERB
# 1154        such   ADJ
# 1155    websites  NOUN
# 1156           .     .
#
# [1157 rows x 2 columns]

# %%
noun = df[df['POS']=='NOUN']

# %%
noun
# Out:
#               WORD   POS
# 0       Cybercrime  NOUN
# 1           police  NOUN
# 5       violations  NOUN
# 7         children  NOUN
# 8         MISUSING  NOUN
# ...            ...   ...
# 1143       Service  NOUN
# 1144       Provid-  NOUN
# 1150  responsibil-  NOUN
# 1151           ers  NOUN
# 1155      websites  NOUN
#
# [372 rows x 2 columns]

# %%
df.to_csv('DetectedPartsofSpeech.csv')

# %%
nouns = list(df[df['POS']=='NOUN'].loc[:,'WORD'])

# %%
print(nouns)
# Out:
# ['Cybercrime', 'police', 'violations', 'children', 'MISUSING', 'SOCIAL', 'MEDIA', 'Experts', 'content', 'trouble', 'Farhan', 'Shaikh', 'farhan.shaikh', '@', 'htlive.com', 'NAVIMUMBAI', 'week', 'Union', 'minister', 'Ravi', 'Shankar', 'Prasad', 'speech', 'Lok', 'Sabha', 'menace', 'child', 'pornog', 'raphy', 'country', 'Navi', 'Mumbai', 'cybercrime', 'cell', 'people', 'city', 'content', 'media', 'week', 'police', 'people', 'crimes', 'officials', 'action', 'people', 'cases', 'people', 'world', 'pro-', 'vides', 'cover', 'anonymity', 'investigations', 'Jayraj', 'Chap-', 'aria', 'police', 'inspector', 'cybercrime', 'cell', 'Navi', 'Mumbai', 'Kopar', 'Khairane', 'police', 'house', 'painter', 'BMS', 'graduate', 'firm', 'Uran', 'police', 'NRI', 'police', 'station', 'person', 'cyber', 'cell', 'sprang', 'action', 'National', 'Cyber', 'Crime', 'Reporting', 'Portal', 'NCCRP', 'URLs', 'web', 'addresses', 'case', 'painter', 'Amit', 'Hussain', 'phone', 'documents', 'mate', 'Hussain', 'Madhya', 'Prade
# ...

# %%
pronouns = list(df[df['POS']=='PRON'].loc[:,'WORD'])

# %%
print(pronouns)
# Out:
# ['what', 'them', 'who', 'We', 'they', 'them', 'our', 'it', 'them', 'his', 'He', 'his', 'he', 'his', 'they', 'his', 'them', 'them', 'we', 'they', 'it', 'them', 'it', 'it', 'you', 'you', 'it', 'it', 'it', 'it', 'their', 'they', 'It', 'who', 'it', 'it', 'she', 'it', 'it', 'they', 'it', 'who', 'it', 'he', 'their', 'they', 'who']

# %%
adj = list(df[df['POS']=='ADJ'].loc[:,'WORD'])

# %%
print(adj)
# Out:
# ['many', 'child', 'porno-', 'graphic', 'social', 'past', 'such', 'more', 'strict', 'many', 'virtual', 'senior', 'private', 'suspected', 'room-', 'pornographic', 'aminor', 'social', 'disrobed', 'ing', 'video', 'strict', 'mis-', 'social', 'sexual', 'circu-', 'central', 'Offi-', 'radic', 'commis-', 'stu-', 'social', 'past', 'child', 'pornographic', 'social', 'mobile', 'social', 'per-', 'likely', 'more', 'such', 'likely', 'mischie-', 'vous', 'aware', 'crime.Compa-', 'more', 'watch-', 'ful', 'social', 'civil-', 'earli-', 'inscribe', 'pornographic', 'pornographic', 'stringent', 'stricter', 'est', 'psychologist', 'users-actual', 'paedo-', 'accidental', 'criminal', 'com-', 'inter-', 'such', 'other', 'social', 'short', 'immediate', 'such', 'villagein', 'rural', 'teenage', 'cou-', 'sexual', 'viral', 'social', 'popular', 'social', 'plat-', 'pro-', 'western', 'eastern', 'most', 'personal', 'available', 'scaling', 'exploita-', 'systematic', 'monetary', 'last', 'extreme', 'worst-of-list', 'wrong',
# ...

# %%
verbs = list(df[df['POS']=='VERB'].loc[:,'WORD'])

# %%
print(verbs)
# Out:
# ['clamp', 'say', 'do', 'know', 'would', 'land', 'growing', 'has', 'identified', 'published', 'have', 'arrested', 'are', 'working', 'trace', 'said', 'aretracing', 'accused', 'will', 'continue', 'are', 'emboldened', 'feel', 'said', 'arrested', 'have', 'arrested', 'working', 'have', 'arrested', 'supplied', 'known', 'bought', 'using', 'arrived', 'find', 'was', 'staying', 'said', 'uploaded', 'involving', 'account', 'traced', 'told', 'found', 'involved', 'said', 'have', 'verified', 'dur-', 'has', 'provided', 'was', 'arrested', 'produced', 'released', 'hope', 'using', 'will', 'be', 'warned', 'indulging', 'said', 'said', 'havenot', 'come', 'sustained', 'is', 'being', 'lated', 'is', 'blocked', 'termed', 'spo-', 'held', 'educate', 'have', 'arrested', 'uploading', 'have', 'seized', 'arrested', 'accused', 'will', 'continue', 'spend', 'would', 'send', 'containing', 'thinking', 'will', 'be', 'ceived', 'added', 'is', 'are', 'arenot', 'known', 'is', 'would', 'post', 'said', 'blamed', 'need', 'be', '
# ...

# %%
adverbs = list(df[df['POS']=='ADV'].loc[:,'WORD'])

# %%
print(adverbs)
# Out:
# ['down', 'not', 'always', 'commonly', 'later', 'allegedly', 'however', 'not', 'where', 'already', 'actively', 'recently', 'quite', 'often', 'how', 'where', 'not', 'just', 'also', 'todo', 'also', 'even', 'cosily', 'not', 'so', 'easily', 'more', 'periodically', 'actively', 'directly', 'then']

# %%
prepo = list(df[df['POS']=='ADP'].loc[:,'WORD'])

# %%
print(prepo)
# Out:
# ['on', 'against', 'in', 'after', 'in', 'on', 'of', 'in', 'across', 'on', 'In', 'for', 'against', 'In', 'as', 'of', 'uncover', 'from', 'Among', 'with', 'while', 'into', 'after', 'with', 'as', 'In', 'of', 'from', 'in', 'in', 'on', 'that', 'with', 'at', 'although', 'with', 'in', 'on', 'With', 'from', 'in', 'at', 'across', 'since', 'at', 'with', 'on', 'of', 'ABOUT', 'of', 'from', 'In', 'for', 'on', 'of', 'with', 'of', 'on', 'out', 'by', 'In', 'of', 'than', 'of', 'In', 'that', 'on', 'on', 'of', 'that', 'at', 'While', 'on', 'during', 'throughout', 'of', 'in', 'of', 'at', 'for', 'for', 'for', 'of', 'on', 'in', 'whether', 'of', 'of', 'of', 'for', 'of', 'of', 'that', 'after', 'at', 'through', 'that', 'in', 'in', 'against', 'In', 'in', 'on', 'on', 'like', 'that', 'above', 'While', 'for', 'in', 'in', 'that', 'of', 'of', 'for', 'of', 'with', 'of', 'From', 'of', 'than', 'from', 'In', 'in', 'of', 'on', 'by', 'of', 'for', 'In', 'with', 'for', 'of', 'on']

# %%
conj = list(df[df['POS']=='CONJ'].loc[:,'WORD'])

# %%
print(conj)
# Out:
# ['and', 'and', 'but', 'and', 'and', 'and', 'and', 'and', 'and', 'and', 'or', 'but', 'and', 'and', 'and', 'and', 'and', 'but', 'and', 'but', 'and', 'and']

# %%
det = list(df[df['POS']=='DET'].loc[:,'WORD'])

# %%
print(det)
# Out:
# ['A', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'a', 'the', 'the', 'a', 'a', 'a', 'the', 'each', 'The', 'the', 'the', 'a', 'a', 'a', 'the', 'a', 'a', 'which', 'The', 'the', 'which', 'a', 'the', 'the', 'a', 'The', 'which', 'the', 'those', 'this', 'a', 'the', 'these', 'a', 'the', 'the', 'the', 'The', 'the', 'the', 'a', 'some', 'a', 'a', 'the', 'a', 'a', 'the', 'a', 'the', 'the', 'a', 'the', 'the', 'a', 'the', 'the', 'these', 'the', 'the', 'a', 'a', 'the', 'which', 'a', 'the', 'a', 'both', 'which', 'a', 'the', 'The', 'the', 'some', 'the', 'the', 'a', 'a', 'The', 'the', 'the', 'The', 'the', 'the', 'The', 'there', 'a', 'the', 'these', 'the', 'the', 'a', 'a', 'the', 'the', 'The', 'the', 'which', 'the', 'The', 'the', 'There', 'a']

# %%
df['POS'].nunique()
# Out:
# 11

# %%
i=0
while(i<1):
    for x in pos:
        POS1 = list(df[df['POS']==x].loc[:,'WORD'])
        print(x,'=',POS1,'\n')
    i=i+1
# Out:
# NOUN = ['Cybercrime', 'police', 'violations', 'children', 'MISUSING', 'SOCIAL', 'MEDIA', 'Experts', 'content', 'trouble', 'Farhan', 'Shaikh', 'farhan.shaikh', '@', 'htlive.com', 'NAVIMUMBAI', 'week', 'Union', 'minister', 'Ravi', 'Shankar', 'Prasad', 'speech', 'Lok', 'Sabha', 'menace', 'child', 'pornog', 'raphy', 'country', 'Navi', 'Mumbai', 'cybercrime', 'cell', 'people', 'city', 'content', 'media', 'week', 'police', 'people', 'crimes', 'officials', 'action', 'people', 'cases', 'people', 'world', 'pro-', 'vides', 'cover', 'anonymity', 'investigations', 'Jayraj', 'Chap-', 'aria', 'police', 'inspector', 'cybercrime', 'cell', 'Navi', 'Mumbai', 'Kopar', 'Khairane', 'police', 'house', 'painter', 'BMS', 'graduate', 'firm', 'Uran', 'police', 'NRI', 'police', 'station', 'person', 'cyber', 'cell', 'sprang', 'action', 'National', 'Cyber', 'Crime', 'Reporting', 'Portal', 'NCCRP', 'URLs', 'web', 'addresses', 'case', 'painter', 'Amit', 'Hussain', 'phone', 'documents', 'mate', 'Hussain', 'Madhya',
# ...
